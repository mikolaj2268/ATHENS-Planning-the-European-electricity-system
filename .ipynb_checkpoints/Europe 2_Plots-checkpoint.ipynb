# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import gurobipy
import numpy as np
# !pip install pypsa[highs] "xarray>=2023.8.0" Cartopy highspy
# Out:
# ^C

# %%
from add_country import *

# %%
import pypsa
import pandas as pd
from dataclasses import dataclass

# %%
add_scandinavia(network, climatic_year, time_horizon_in_hours)
# Out:
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:The bus name `Curtailment` given for bus of Load `scandinaviaCurtailment-load` does not appear in network.buses

# %%
add_germany(network, climatic_year, time_horizon_in_hours)
add_iberian(network, climatic_year, time_horizon_in_hours)
add_poland(network, climatic_year, time_horizon_in_hours)
add_france(network, climatic_year, time_horizon_in_hours)
# Out:
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:The bus name `Curtailment` given for bus of Load `iberianCurtailment-load` does not appear in network.buses
# WARNING:pypsa.components:The bus name `Curtailment` given for bus of Load `polandCurtailment-load` does not appear in network.buses
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:The bus name `Curtailment` given for bus of Load `FranceCurtailment-load` does not appear in network.buses

# %%
network.generators
# Out:
# attribute                                            bus control type  \
# Generator
# scandinaviaFossils                           Scandinavia      PQ
# scandinaviaBioEnergies                       Scandinavia      PQ
# scandinaviaHydroelectric                     Scandinavia      PQ
# scandinaviaWind_on_shore                     Scandinavia      PQ
# scandinaviaWind_off_shore                    Scandinavia      PQ
# scandinaviaNuclear                           Scandinavia      PQ
# scandinaviaSolar                             Scandinavia      PQ
# scandinaviaFailure                           Scandinavia      PQ
# GER-Hydro_ROR                                    Germany      PQ
# GER-WindOnshore                                  Germany      PQ
# GER-WindOffshore                                 Germany      PQ
# GER-Solar                                        Germany      PQ
# GER-Coal                                         Germany      PQ
# GER-Biomass                                      Germany      PQ
# GER-CCGT                                         Germany      PQ
# GER-Oil                                          Germany      PQ
# GER-Underproduction                              Germany      PQ
# iberianFossils                         Iberian_Peninsula      PQ
# iberianBioEnergies                     Iberian_Peninsula      PQ
# iberianHydroelectric                   Iberian_Peninsula      PQ
# iberianWind_on_shore                   Iberian_Peninsula      PQ
# iberianWind_off_shore                  Iberian_Peninsula      PQ
# iberianNuclear                         Iberian_Peninsula      PQ
# iberianSolar                           Iberian_Peninsula      PQ
# iberianFailure                         Iberian_Peninsula      PQ
# poland_Hydro - Run of River (Turbine)             poland      PQ
# poland_Wind Onshore                               poland      PQ
# poland_Wind Offshore                              poland      PQ
# poland_Solar (Photovoltaic)                       poland      PQ
# poland_Biofuel                                    poland      PQ
# poland_Others renewable                           poland      PQ
# polandFailure                                     poland      PQ
# FranceNuclear                                     France      PQ
# FranceWindOnshore                                 France      PQ
# FranceWindOffshore                                France      PQ
# FranceSolar                                       France      PQ
# FranceOCGT                                        France      PQ
# FranceBioEnergies                                 France      PQ
# FranceHydro                                       France      PQ
# FranceFailure                                     France      PQ
#
# attribute                                  p_nom  p_nom_extendable  p_nom_min  \
# Generator
# scandinaviaFossils                        5000.0             False        0.0
# scandinaviaBioEnergies                   11000.0             False        0.0
# scandinaviaHydroelectric                 57000.0             False        0.0
# scandinaviaWind_on_shore                 43000.0             False        0.0
# scandinaviaWind_off_shore                17000.0             False        0.0
# scandinaviaNuclear                       11000.0             False        0.0
# scandinaviaSolar                         19000.0             False        0.0
# scandinaviaFailure                      100000.0             False        0.0
# GER-Hydro_ROR                             3933.0             False        0.0
# GER-WindOnshore                         115000.0             False        0.0
# GER-WindOffshore                         30185.0             False        0.0
# GER-Solar                               215002.0             False        0.0
# GER-Coal                                     0.0             False        0.0
# GER-Biomass                              13067.0             False        0.0
# GER-CCGT                                 35504.0             False        0.0
# GER-Oil                                   1885.0             False        0.0
# GER-Underproduction                    1000000.0             False        0.0
# iberianFossils                            2139.0             False        0.0
# iberianBioEnergies                           0.0             False        0.0
# iberianHydroelectric                      4196.0             False        0.0
# iberianWind_on_shore                     57017.0             False        0.0
# iberianWind_off_shore                     3046.0             False        0.0
# iberianNuclear                            5100.0             False        0.0
# iberianSolar                             80606.0             False        0.0
# iberianFailure                          100000.0             False        0.0
# poland_Hydro - Run of River (Turbine)      367.0             False        0.0
# poland_Wind Onshore                      13768.0             False        0.0
# poland_Wind Offshore                      9644.0             False        0.0
# poland_Solar (Photovoltaic)              21663.0             False        0.0
# poland_Biofuel                             728.0             False        0.0
# poland_Others renewable                   2155.0             False        0.0
# polandFailure                           100000.0             False        0.0
# FranceNuclear                            59400.0             False        0.0
# FranceWindOnshore                        11000.0             False        0.0
# FranceWindOffshore                        5800.0             False        0.0
# FranceSolar                              47300.0             False        0.0
# FranceOCGT                                6700.0             False        0.0
# FranceBioEnergies                         2300.0             False        0.0
# FranceHydro                              26900.0             False        0.0
# FranceFailure                           100000.0             False        0.0
#
# attribute                              p_nom_max  p_min_pu  p_max_pu  p_set  \
# Generator
# scandinaviaFossils                           inf       0.0       1.0    0.0
# scandinaviaBioEnergies                       inf       0.0       1.0    0.0
# scandinaviaHydroelectric                     inf       0.0       1.0    0.0
# scandinaviaWind_on_shore                     inf       0.0       1.0    0.0
# scandinaviaWind_off_shore                    inf       0.0       1.0    0.0
# scandinaviaNuclear                           inf       0.0       1.0    0.0
# scandinaviaSolar                             inf       0.0       1.0    0.0
# scandinaviaFailure                           inf       0.0       1.0    0.0
# GER-Hydro_ROR                                inf       0.0       1.0    0.0
# GER-WindOnshore                              inf       0.0       1.0    0.0
# GER-WindOffshore                             inf       0.0       1.0    0.0
# GER-Solar                                    inf       0.0       1.0    0.0
# GER-Coal                                     inf       0.0       1.0    0.0
# GER-Biomass                                  inf       0.0       1.0    0.0
# GER-CCGT                                     inf       0.0       1.0    0.0
# GER-Oil                                      inf       0.0       1.0    0.0
# GER-Underproduction                          inf       0.0       1.0    0.0
# iberianFossils                               inf       0.0       1.0    0.0
# iberianBioEnergies                           inf       0.0       1.0    0.0
# iberianHydroelectric                         inf       0.0       1.0    0.0
# iberianWind_on_shore                         inf       0.0       1.0    0.0
# iberianWind_off_shore                        inf       0.0       1.0    0.0
# iberianNuclear                               inf       0.0       1.0    0.0
# iberianSolar                                 inf       0.0       1.0    0.0
# iberianFailure                               inf       0.0       1.0    0.0
# poland_Hydro - Run of River (Turbine)        inf       0.0       1.0    0.0
# poland_Wind Onshore                          inf       0.0       1.0    0.0
# poland_Wind Offshore                         inf       0.0       1.0    0.0
# poland_Solar (Photovoltaic)                  inf       0.0       1.0    0.0
# poland_Biofuel                               inf       0.0       1.0    0.0
# poland_Others renewable                      inf       0.0       1.0    0.0
# polandFailure                                inf       0.0       1.0    0.0
# FranceNuclear                                inf       0.3       1.0    0.0
# FranceWindOnshore                            inf       0.0       1.0    0.0
# FranceWindOffshore                           inf       0.0       1.0    0.0
# FranceSolar                                  inf       0.0       1.0    0.0
# FranceOCGT                                   inf       0.0       1.0    0.0
# FranceBioEnergies                            inf       0.0       1.0    0.0
# FranceHydro                                  inf       0.0       1.0    0.0
# FranceFailure                                inf       0.0       1.0    0.0
#
# attribute                              ...  min_up_time  min_down_time  \
# Generator                              ...
# scandinaviaFossils                     ...            1              1
# scandinaviaBioEnergies                 ...            1              1
# scandinaviaHydroelectric               ...            1              1
# scandinaviaWind_on_shore               ...            1              1
# scandinaviaWind_off_shore              ...            1              1
# scandinaviaNuclear                     ...           24             24
# scandinaviaSolar                       ...            1              1
# scandinaviaFailure                     ...            1              1
# GER-Hydro_ROR                          ...            0              0
# GER-WindOnshore                        ...            0              0
# GER-WindOffshore                       ...            0              0
# GER-Solar                              ...            0              0
# GER-Coal                               ...           24             24
# GER-Biomass                            ...           12             12
# GER-CCGT                               ...            0              0
# GER-Oil                                ...            1              1
# GER-Underproduction                    ...            0              0
# iberianFossils                         ...            1              1
# iberianBioEnergies                     ...            1              1
# iberianHydroelectric                   ...            1              1
# iberianWind_on_shore                   ...            1              1
# iberianWind_off_shore                  ...            1              1
# iberianNuclear                         ...           24             24
# iberianSolar                           ...            1              1
# iberianFailure                         ...            1              1
# poland_Hydro - Run of River (Turbine)  ...            1              1
# poland_Wind Onshore                    ...            1              1
# poland_Wind Offshore                   ...            1              1
# poland_Solar (Photovoltaic)            ...            1              1
# poland_Biofuel                         ...            1              1
# poland_Others renewable                ...            1              1
# polandFailure                          ...            1              1
# FranceNuclear                          ...           24             24
# FranceWindOnshore                      ...            1              1
# FranceWindOffshore                     ...            1              1
# FranceSolar                            ...            1              1
# FranceOCGT                             ...            1              1
# FranceBioEnergies                      ...            1              1
# FranceHydro                            ...            1              1
# FranceFailure                          ...            1              1
#
# attribute                             up_time_before  down_time_before  \
# Generator
# scandinaviaFossils                                 1                 0
# scandinaviaBioEnergies                             1                 0
# scandinaviaHydroelectric                           1                 0
# scandinaviaWind_on_shore                           1                 0
# scandinaviaWind_off_shore                          1                 0
# scandinaviaNuclear                                 1                 0
# scandinaviaSolar                                   1                 0
# scandinaviaFailure                                 1                 0
# GER-Hydro_ROR                                      1                 0
# GER-WindOnshore                                    1                 0
# GER-WindOffshore                                   1                 0
# GER-Solar                                          1                 0
# GER-Coal                                           1                 0
# GER-Biomass                                        1                 0
# GER-CCGT                                           1                 0
# GER-Oil                                            1                 0
# GER-Underproduction                                1                 0
# iberianFossils                                     1                 0
# iberianBioEnergies                                 1                 0
# iberianHydroelectric                               1                 0
# iberianWind_on_shore                               1                 0
# iberianWind_off_shore                              1                 0
# iberianNuclear                                     1                 0
# iberianSolar                                       1                 0
# iberianFailure                                     1                 0
# poland_Hydro - Run of River (Turbine)              1                 0
# poland_Wind Onshore                                1                 0
# poland_Wind Offshore                               1                 0
# poland_Solar (Photovoltaic)                        1                 0
# poland_Biofuel                                     1                 0
# poland_Others renewable                            1                 0
# polandFailure                                      1                 0
# FranceNuclear                                      1                 0
# FranceWindOnshore                                  1                 0
# FranceWindOffshore                                 1                 0
# FranceSolar                                        1                 0
# FranceOCGT                                         1                 0
# FranceBioEnergies                                  1                 0
# FranceHydro                                        1                 0
# FranceFailure                                      1                 0
#
# attribute                              ramp_limit_up  ramp_limit_down  \
# Generator
# scandinaviaFossils                               NaN              NaN
# scandinaviaBioEnergies                           NaN              NaN
# scandinaviaHydroelectric                         NaN              NaN
# scandinaviaWind_on_shore                         NaN              NaN
# scandinaviaWind_off_shore                        NaN              NaN
# scandinaviaNuclear                               NaN              NaN
# scandinaviaSolar                                 NaN              NaN
# scandinaviaFailure                               NaN              NaN
# GER-Hydro_ROR                                    NaN              NaN
# GER-WindOnshore                                  NaN              NaN
# GER-WindOffshore                                 NaN              NaN
# GER-Solar                                        NaN              NaN
# GER-Coal                                         NaN              NaN
# GER-Biomass                                      NaN              NaN
# GER-CCGT                                         NaN              NaN
# GER-Oil                                          NaN              NaN
# GER-Underproduction                              NaN              NaN
# iberianFossils                                   NaN              NaN
# iberianBioEnergies                               NaN              NaN
# iberianHydroelectric                             NaN              NaN
# iberianWind_on_shore                             NaN              NaN
# iberianWind_off_shore                            NaN              NaN
# iberianNuclear                                   NaN              NaN
# iberianSolar                                     NaN              NaN
# iberianFailure                                   NaN              NaN
# poland_Hydro - Run of River (Turbine)            NaN              NaN
# poland_Wind Onshore                              NaN              NaN
# poland_Wind Offshore                             NaN              NaN
# poland_Solar (Photovoltaic)                      NaN              NaN
# poland_Biofuel                                   NaN              NaN
# poland_Others renewable                          NaN              NaN
# polandFailure                                    NaN              NaN
# FranceNuclear                                    NaN              NaN
# FranceWindOnshore                                NaN              NaN
# FranceWindOffshore                               NaN              NaN
# FranceSolar                                      NaN              NaN
# FranceOCGT                                       NaN              NaN
# FranceBioEnergies                                NaN              NaN
# FranceHydro                                      NaN              NaN
# FranceFailure                                    NaN              NaN
#
# attribute                              ramp_limit_start_up  \
# Generator
# scandinaviaFossils                                     1.0
# scandinaviaBioEnergies                                 1.0
# scandinaviaHydroelectric                               1.0
# scandinaviaWind_on_shore                               1.0
# scandinaviaWind_off_shore                              1.0
# scandinaviaNuclear                                     1.0
# scandinaviaSolar                                       1.0
# scandinaviaFailure                                     1.0
# GER-Hydro_ROR                                          1.0
# GER-WindOnshore                                        1.0
# GER-WindOffshore                                       1.0
# GER-Solar                                              1.0
# GER-Coal                                               1.0
# GER-Biomass                                            1.0
# GER-CCGT                                               1.0
# GER-Oil                                                1.0
# GER-Underproduction                                    1.0
# iberianFossils                                         1.0
# iberianBioEnergies                                     1.0
# iberianHydroelectric                                   1.0
# iberianWind_on_shore                                   1.0
# iberianWind_off_shore                                  1.0
# iberianNuclear                                         1.0
# iberianSolar                                           1.0
# iberianFailure                                         1.0
# poland_Hydro - Run of River (Turbine)                  1.0
# poland_Wind Onshore                                    1.0
# poland_Wind Offshore                                   1.0
# poland_Solar (Photovoltaic)                            1.0
# poland_Biofuel                                         1.0
# poland_Others renewable                                1.0
# polandFailure                                          1.0
# FranceNuclear                                          1.0
# FranceWindOnshore                                      1.0
# FranceWindOffshore                                     1.0
# FranceSolar                                            1.0
# FranceOCGT                                             1.0
# FranceBioEnergies                                      1.0
# FranceHydro                                            1.0
# FranceFailure                                          1.0
#
# attribute                              ramp_limit_shut_down  weight  p_nom_opt
# Generator
# scandinaviaFossils                                      1.0     1.0        0.0
# scandinaviaBioEnergies                                  1.0     1.0        0.0
# scandinaviaHydroelectric                                1.0     1.0        0.0
# scandinaviaWind_on_shore                                1.0     1.0        0.0
# scandinaviaWind_off_shore                               1.0     1.0        0.0
# scandinaviaNuclear                                      1.0     1.0        0.0
# scandinaviaSolar                                        1.0     1.0        0.0
# scandinaviaFailure                                      1.0     1.0        0.0
# GER-Hydro_ROR                                           1.0     1.0        0.0
# GER-WindOnshore                                         1.0     1.0        0.0
# GER-WindOffshore                                        1.0     1.0        0.0
# GER-Solar                                               1.0     1.0        0.0
# GER-Coal                                                1.0     1.0        0.0
# GER-Biomass                                             1.0     1.0        0.0
# GER-CCGT                                                1.0     1.0        0.0
# GER-Oil                                                 1.0     1.0        0.0
# GER-Underproduction                                     1.0     1.0        0.0
# iberianFossils                                          1.0     1.0        0.0
# iberianBioEnergies                                      1.0     1.0        0.0
# iberianHydroelectric                                    1.0     1.0        0.0
# iberianWind_on_shore                                    1.0     1.0        0.0
# iberianWind_off_shore                                   1.0     1.0        0.0
# iberianNuclear                                          1.0     1.0        0.0
# iberianSolar                                            1.0     1.0        0.0
# iberianFailure                                          1.0     1.0        0.0
# poland_Hydro - Run of River (Turbine)                   1.0     1.0        0.0
# poland_Wind Onshore                                     1.0     1.0        0.0
# poland_Wind Offshore                                    1.0     1.0        0.0
# poland_Solar (Photovoltaic)                             1.0     1.0        0.0
# poland_Biofuel                                          1.0     1.0        0.0
# poland_Others renewable                                 1.0     1.0        0.0
# polandFailure                                           1.0     1.0        0.0
# FranceNuclear                                           1.0     1.0        0.0
# FranceWindOnshore                                       1.0     1.0        0.0
# FranceWindOffshore                                      1.0     1.0        0.0
# FranceSolar                                             1.0     1.0        0.0
# FranceOCGT                                              1.0     1.0        0.0
# FranceBioEnergies                                       1.0     1.0        0.0
# FranceHydro                                             1.0     1.0        0.0
# FranceFailure                                           1.0     1.0        0.0
#
# [40 rows x 33 columns]

# %%
network
# Out:
# PyPSA Network
# Components:
#  - Bus: 5
#  - Carrier: 19
#  - Generator: 40
#  - Load: 9
#  - StorageUnit: 6
#  - Store: 11
# Snapshots: 8760

# %%
links_list = [
    {"name" : "Link_SCA_Curtailment", "bus0" : "Scandinavia", "bus1" : "Curtailment", "p_nom" : 700000, "efficiency" : 0.95},
    {"name" : "Link_SCA_Germany", "bus0":"Scandinavia", "bus1":"Germany", "p_nom":7415, "efficiency":0.95},
    {"name" : "Link_SCA_Poland", "bus0":"Scandinavia", "bus1":"poland", "p_nom":600, "efficiency":0.95},
    #{"name" : "Link_SCA_Benelux", "bus0":"Scandinavia", "bus1":"Benelux", "p_nom":1400, "efficiency":0.95},
    #{"name" : "Link_Benelux_SCA", "bus0":"Benelux", "bus1":"Scandinavia", "p_nom":1400, "efficiency":0.95},
    {"name" : "Link_Poland_SCA", "bus0":"poland", "bus1":"Scandinavia", "p_nom":600, "efficiency":0.95},
    {"name" : "Link_Germany_SCA", "bus0":"Germany", "bus1":"Scandinavia", "p_nom":2000, "efficiency":0.95},
    {"name" : "Link_France_Germany", "bus0":"France", "bus1":"Germany", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_France", "bus0":"Germany", "bus1":"France", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_Poland", "bus0":"Germany", "bus1":"poland", "p_nom":3400, "efficiency":0.95},
    {"name" : "Link_Poland_Germany", "bus0":"poland", "bus1":"Germany", "p_nom":3400, "efficiency":0.95},
    #{"name" : "Link_Germany_Benelux", "bus0":"Germany", "bus1":"Benelux", "p_nom":9300, "efficiency":0.95},
    #{"name" : "Link_Benelux_Germany", "bus0":"Benelux", "bus1":"Germany", "p_nom":9300, "efficiency":0.95},
    #{"name" : "Link_Benelux_France", "bus0":"Benelux", "bus1":"France", "p_nom":4680, "efficiency":0.95},
    #{"name" : "Link_France_Benelux", "bus0":"France", "bus1":"Benelux", "p_nom":4680, "efficiency":0.95},
    {"name" : "Link_France_Iberian", "bus0":"France", "bus1":"Iberian_Peninsula", "p_nom":5000, "efficiency":0.95},
    {"name" : "Link_Iberian_France", "bus0":"Iberian_Peninsula", "bus1":"France", "p_nom":5000, "efficiency":0.95},
]

for links in links_list:
    network.add("Link", **links,)
# Out:
# WARNING:pypsa.components:The bus name `Curtailment` given for bus1 of Link `Link_SCA_Curtailment` does not appear in network.buses

# %%
network.plot(
    title="European Electricity Network",
    color_geomap=True,
    jitter=0.3,
)
# Out:
# WARNING:pypsa.plot:Cartopy needs to be installed to use `geomap=True`.
# (<matplotlib.collections.PatchCollection at 0x28c52faf5e0>,
#  <matplotlib.collections.LineCollection at 0x28c52f58310>)

# %%
result = network.optimize(solver_name="gurobi")
print(result)
# Out:
# WARNING:pypsa.components:The following loads have bus which are not defined:
# Index(['scandinaviaCurtailment-load', 'iberianCurtailment-load',
#        'polandCurtailment-load', 'FranceCurtailment-load'],
#       dtype='object', name='Load')
# WARNING:pypsa.components:The following links have bus1 which are not defined:
# Index(['Link_SCA_Curtailment'], dtype='object', name='Link')
# WARNING:pypsa.components:The following loads have bus which are not defined:
# Index(['scandinaviaCurtailment-load', 'iberianCurtailment-load',
#        'polandCurtailment-load', 'FranceCurtailment-load'],
#       dtype='object', name='Load')
# WARNING:pypsa.components:The following links have bus1 which are not defined:
# Index(['Link_SCA_Curtailment'], dtype='object', name='Link')
# INFO:linopy.model: Solve problem using Gurobi solver
# Set parameter WLSAccessID
# INFO:gurobipy.gurobipy:Set parameter WLSAccessID
# Set parameter WLSSecret
# INFO:gurobipy.gurobipy:Set parameter WLSSecret
# Set parameter LicenseID to value 2442949
# INFO:gurobipy.gurobipy:Set parameter LicenseID to value 2442949
# Academic license 2442949 - for non-commercial use only - registered to m.___@student.tudelft.nl
# INFO:gurobipy.gurobipy:Academic license 2442949 - for non-commercial use only - registered to m.___@student.tudelft.nl
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|██████████| 22/22 [00:15<00:00,  1.40it/s]
# Writing continuous variables.: 100%|██████████| 8/8 [00:02<00:00,  3.60it/s]
# Writing binary variables.: 100%|██████████| 3/3 [00:00<00:00,  8.16it/s]
# INFO:linopy.io: Writing time: 18.95s
# Read LP format model from file C:\Users\donal\AppData\Local\Temp\linopy-problem-rwt3pxu_.lp
# INFO:gurobipy.gurobipy:Read LP format model from file C:\Users\donal\AppData\Local\Temp\linopy-problem-rwt3pxu_.lp
# Reading time = 4.74 seconds
# INFO:gurobipy.gurobipy:Reading time = 4.74 seconds
# obj: 1979761 rows, 1086240 columns, 4124986 nonzeros
# INFO:gurobipy.gurobipy:obj: 1979761 rows, 1086240 columns, 4124986 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (win64)
# INFO:gurobipy.gurobipy:
# CPU model: AMD Ryzen 5 4600H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# INFO:gurobipy.gurobipy:CPU model: AMD Ryzen 5 4600H with Radeon Graphics, instruction set [SSE2|AVX|AVX2]
# Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# INFO:gurobipy.gurobipy:Thread count: 6 physical cores, 12 logical processors, using up to 12 threads
# INFO:gurobipy.gurobipy:
# Academic license 2442949 - for non-commercial use only - registered to m.___@student.tudelft.nl
# INFO:gurobipy.gurobipy:Academic license 2442949 - for non-commercial use only - registered to m.___@student.tudelft.nl
# Optimize a model with 1979761 rows, 1086240 columns and 4124986 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 1979761 rows, 1086240 columns and 4124986 nonzeros
# Model fingerprint: 0x77da0c2f
# INFO:gurobipy.gurobipy:Model fingerprint: 0x77da0c2f
# Variable types: 797160 continuous, 289080 integer (289080 binary)
# INFO:gurobipy.gurobipy:Variable types: 797160 continuous, 289080 integer (289080 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [9e-01, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [9e-01, 1e+05]
#   Objective range  [5e+00, 1e+07]
# INFO:gurobipy.gurobipy:  Objective range  [5e+00, 1e+07]
#   Bounds range     [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+06]
# INFO:gurobipy.gurobipy:  RHS range        [1e+00, 1e+06]
# Presolve removed 1853393 rows and 778355 columns (presolve time = 5s) ...
# INFO:gurobipy.gurobipy:Presolve removed 1853393 rows and 778355 columns (presolve time = 5s) ...
# Presolve removed 1855660 rows and 834274 columns (presolve time = 19s) ...
# INFO:gurobipy.gurobipy:Presolve removed 1855660 rows and 834274 columns (presolve time = 19s) ...
# Presolve removed 1862747 rows and 834274 columns
# INFO:gurobipy.gurobipy:Presolve removed 1862747 rows and 834274 columns
# Presolve time: 19.28s
# INFO:gurobipy.gurobipy:Presolve time: 19.28s
# Presolved: 117014 rows, 251966 columns, 953875 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 117014 rows, 251966 columns, 953875 nonzeros
# Variable types: 209945 continuous, 42021 integer (41904 binary)
# INFO:gurobipy.gurobipy:Variable types: 209945 continuous, 42021 integer (41904 binary)
# Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# INFO:gurobipy.gurobipy:Deterministic concurrent LP optimizer: primal simplex, dual simplex, and barrier
# Showing barrier log only...
# INFO:gurobipy.gurobipy:Showing barrier log only...
# INFO:gurobipy.gurobipy:
# Root barrier log...
# INFO:gurobipy.gurobipy:Root barrier log...
# INFO:gurobipy.gurobipy:
# Ordering time: 0.21s
# INFO:gurobipy.gurobipy:Ordering time: 0.21s
# INFO:gurobipy.gurobipy:
# Barrier statistics:
# INFO:gurobipy.gurobipy:Barrier statistics:
#  AA' NZ     : 1.469e+06
# INFO:gurobipy.gurobipy: AA' NZ     : 1.469e+06
#  Factor NZ  : 4.815e+06 (roughly 180 MB of memory)
# INFO:gurobipy.gurobipy: Factor NZ  : 4.815e+06 (roughly 180 MB of memory)
#  Factor Ops : 3.815e+08 (less than 1 second per iteration)
# INFO:gurobipy.gurobipy: Factor Ops : 3.815e+08 (less than 1 second per iteration)
#  Threads    : 3
# INFO:gurobipy.gurobipy: Threads    : 3
# INFO:gurobipy.gurobipy:
#                   Objective                Residual
# INFO:gurobipy.gurobipy:                  Objective                Residual
# Iter       Primal          Dual         Primal    Dual     Compl     Time
# INFO:gurobipy.gurobipy:Iter       Primal          Dual         Primal    Dual     Compl     Time
#    0  -2.45563003e+15 -4.39701018e+18  2.22e+05 1.49e+09  4.26e+13    23s
# INFO:gurobipy.gurobipy:   0  -2.45563003e+15 -4.39701018e+18  2.22e+05 1.49e+09  4.26e+13    23s
#    1  -7.49371122e+14 -2.20666656e+18  7.31e+04 1.37e+09  1.56e+13    23s
# INFO:gurobipy.gurobipy:   1  -7.49371122e+14 -2.20666656e+18  7.31e+04 1.37e+09  1.56e+13    23s
#    2  -4.94991824e+13 -8.00496851e+17  2.05e+04 2.22e+08  4.47e+12    23s
# INFO:gurobipy.gurobipy:   2  -4.94991824e+13 -8.00496851e+17  2.05e+04 2.22e+08  4.47e+12    23s
#    3   1.95363925e+14 -2.36525092e+17  1.88e+03 3.28e+06  6.49e+11    23s
# INFO:gurobipy.gurobipy:   3   1.95363925e+14 -2.36525092e+17  1.88e+03 3.28e+06  6.49e+11    23s
#    4   1.96712450e+14 -1.08250249e+17  1.00e+03 1.02e+06  2.74e+11    24s
# INFO:gurobipy.gurobipy:   4   1.96712450e+14 -1.08250249e+17  1.00e+03 1.02e+06  2.74e+11    24s
#    5   1.87435034e+14 -6.95888692e+16  6.75e+02 5.09e+04  1.69e+11    24s
# INFO:gurobipy.gurobipy:   5   1.87435034e+14 -6.95888692e+16  6.75e+02 5.09e+04  1.69e+11    24s
#    6   1.42651864e+14 -1.73433763e+16  3.02e+02 6.68e-06  4.28e+10    24s
# INFO:gurobipy.gurobipy:   6   1.42651864e+14 -1.73433763e+16  3.02e+02 6.68e-06  4.28e+10    24s
#    7   6.87753952e+13 -8.24052022e+15  6.86e+01 5.25e-06  1.74e+10    24s
# INFO:gurobipy.gurobipy:   7   6.87753952e+13 -8.24052022e+15  6.86e+01 5.25e-06  1.74e+10    24s
#    8   4.56222617e+13 -2.11385129e+15  1.92e+01 6.68e-06  4.41e+09    24s
# INFO:gurobipy.gurobipy:   8   4.56222617e+13 -2.11385129e+15  1.92e+01 6.68e-06  4.41e+09    24s
#    9   3.41626114e+13 -3.14952618e+14  5.84e+00 5.25e-06  7.37e+08    25s
# INFO:gurobipy.gurobipy:   9   3.41626114e+13 -3.14952618e+14  5.84e+00 5.25e-06  7.37e+08    25s
#   10   2.52760907e+13 -1.84449945e+14  2.28e+00 5.13e-06  4.23e+08    25s
# INFO:gurobipy.gurobipy:  10   2.52760907e+13 -1.84449945e+14  2.28e+00 5.13e-06  4.23e+08    25s
#   11   2.15449199e+13 -8.14575386e+13  1.12e+00 5.25e-06  2.05e+08    25s
# INFO:gurobipy.gurobipy:  11   2.15449199e+13 -8.14575386e+13  1.12e+00 5.25e-06  2.05e+08    25s
#   12   1.89349766e+13 -1.89646499e+13  4.94e-01 4.53e-06  7.48e+07    25s
# INFO:gurobipy.gurobipy:  12   1.89349766e+13 -1.89646499e+13  4.94e-01 4.53e-06  7.48e+07    25s
#   13   1.73068009e+13  5.04261453e+12  1.94e-01 2.67e-06  2.38e+07    25s
# INFO:gurobipy.gurobipy:  13   1.73068009e+13  5.04261453e+12  1.94e-01 2.67e-06  2.38e+07    25s
#   14   1.63896588e+13  1.32251510e+13  5.05e-02 1.24e-06  6.04e+06    25s
# INFO:gurobipy.gurobipy:  14   1.63896588e+13  1.32251510e+13  5.05e-02 1.24e-06  6.04e+06    25s
#   15   1.60825476e+13  1.46321775e+13  1.79e-02 5.76e-07  2.75e+06    26s
# INFO:gurobipy.gurobipy:  15   1.60825476e+13  1.46321775e+13  1.79e-02 5.76e-07  2.75e+06    26s
#   16   1.59845884e+13  1.54063868e+13  9.14e-03 2.29e-07  1.10e+06    26s
# INFO:gurobipy.gurobipy:  16   1.59845884e+13  1.54063868e+13  9.14e-03 2.29e-07  1.10e+06    26s
#   17   1.59343273e+13  1.56729112e+13  4.91e-03 1.02e-07  4.96e+05    26s
# INFO:gurobipy.gurobipy:  17   1.59343273e+13  1.56729112e+13  4.91e-03 1.02e-07  4.96e+05    26s
#   18   1.59100849e+13  1.58051105e+13  3.06e-03 3.94e-08  2.00e+05    26s
# INFO:gurobipy.gurobipy:  18   1.59100849e+13  1.58051105e+13  3.06e-03 3.94e-08  2.00e+05    26s
#   19   1.58806584e+13  1.58490318e+13  9.27e-04 3.76e-08  6.02e+04    27s
# INFO:gurobipy.gurobipy:  19   1.58806584e+13  1.58490318e+13  9.27e-04 3.76e-08  6.02e+04    27s
#   20   1.58738156e+13  1.58551510e+13  4.77e-04 3.62e-08  3.55e+04    27s
# INFO:gurobipy.gurobipy:  20   1.58738156e+13  1.58551510e+13  4.77e-04 3.62e-08  3.55e+04    27s
#   21   1.58711252e+13  1.58591041e+13  3.04e-04 2.98e-08  2.29e+04    27s
# INFO:gurobipy.gurobipy:  21   1.58711252e+13  1.58591041e+13  3.04e-04 2.98e-08  2.29e+04    27s
#   22   1.58697100e+13  1.58612285e+13  2.15e-04 2.98e-08  1.61e+04    27s
# INFO:gurobipy.gurobipy:  22   1.58697100e+13  1.58612285e+13  2.15e-04 2.98e-08  1.61e+04    27s
#   23   1.58684586e+13  1.58641717e+13  1.44e-04 3.30e-08  8.17e+03    28s
# INFO:gurobipy.gurobipy:  23   1.58684586e+13  1.58641717e+13  1.44e-04 3.30e-08  8.17e+03    28s
#   24   1.58679247e+13  1.58645429e+13  1.11e-04 3.34e-08  6.45e+03    28s
# INFO:gurobipy.gurobipy:  24   1.58679247e+13  1.58645429e+13  1.11e-04 3.34e-08  6.45e+03    28s
#   25   1.58671872e+13  1.58650988e+13  6.71e-05 3.36e-08  3.98e+03    28s
# INFO:gurobipy.gurobipy:  25   1.58671872e+13  1.58650988e+13  6.71e-05 3.36e-08  3.98e+03    28s
#   26   1.58667970e+13  1.58656373e+13  4.44e-05 2.98e-08  2.21e+03    28s
# INFO:gurobipy.gurobipy:  26   1.58667970e+13  1.58656373e+13  4.44e-05 2.98e-08  2.21e+03    28s
#   27   1.58666615e+13  1.58657804e+13  3.57e-05 2.98e-08  1.68e+03    29s
# INFO:gurobipy.gurobipy:  27   1.58666615e+13  1.58657804e+13  3.57e-05 2.98e-08  1.68e+03    29s
#   28   1.58665550e+13  1.58658493e+13  2.89e-05 2.98e-08  1.35e+03    29s
# INFO:gurobipy.gurobipy:  28   1.58665550e+13  1.58658493e+13  2.89e-05 2.98e-08  1.35e+03    29s
#   29   1.58664791e+13  1.58659031e+13  2.42e-05 2.98e-08  1.10e+03    29s
# INFO:gurobipy.gurobipy:  29   1.58664791e+13  1.58659031e+13  2.42e-05 2.98e-08  1.10e+03    29s
#   30   1.58663573e+13  1.58659813e+13  1.68e-05 2.98e-08  7.19e+02    29s
# INFO:gurobipy.gurobipy:  30   1.58663573e+13  1.58659813e+13  1.68e-05 2.98e-08  7.19e+02    29s
#   31   1.58662383e+13  1.58660067e+13  9.39e-06 2.98e-08  4.42e+02    30s
# INFO:gurobipy.gurobipy:  31   1.58662383e+13  1.58660067e+13  9.39e-06 2.98e-08  4.42e+02    30s
#   32   1.58661896e+13  1.58660409e+13  6.35e-06 2.40e-08  2.84e+02    30s
# INFO:gurobipy.gurobipy:  32   1.58661896e+13  1.58660409e+13  6.35e-06 2.40e-08  2.84e+02    30s
#   33   1.58661650e+13  1.58660578e+13  4.75e-06 3.15e-08  2.05e+02    30s
# INFO:gurobipy.gurobipy:  33   1.58661650e+13  1.58660578e+13  4.75e-06 3.15e-08  2.05e+02    30s
#   34   1.58661441e+13  1.58660668e+13  3.43e-06 3.59e-08  1.48e+02    30s
# INFO:gurobipy.gurobipy:  34   1.58661441e+13  1.58660668e+13  3.43e-06 3.59e-08  1.48e+02    30s
#   35   1.58661345e+13  1.58660724e+13  2.82e-06 2.98e-08  1.19e+02    30s
# INFO:gurobipy.gurobipy:  35   1.58661345e+13  1.58660724e+13  2.82e-06 2.98e-08  1.19e+02    30s
# INFO:gurobipy.gurobipy:
# Barrier performed 35 iterations in 30.43 seconds (14.33 work units)
# INFO:gurobipy.gurobipy:Barrier performed 35 iterations in 30.43 seconds (14.33 work units)
# Barrier solve interrupted - model solved by another algorithm
# INFO:gurobipy.gurobipy:Barrier solve interrupted - model solved by another algorithm
# INFO:gurobipy.gurobipy:
# Concurrent spin time: 0.05s
# INFO:gurobipy.gurobipy:Concurrent spin time: 0.05s
# INFO:gurobipy.gurobipy:
# Solved with dual simplex
# INFO:gurobipy.gurobipy:Solved with dual simplex
# INFO:gurobipy.gurobipy:
# Root simplex log...
# INFO:gurobipy.gurobipy:Root simplex log...
# INFO:gurobipy.gurobipy:
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# INFO:gurobipy.gurobipy:Iteration    Objective       Primal Inf.    Dual Inf.      Time
#    92297    1.5866090e+13   0.000000e+00   0.000000e+00     31s
# INFO:gurobipy.gurobipy:   92297    1.5866090e+13   0.000000e+00   0.000000e+00     31s
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 1.586609e+13, 92297 iterations, 9.91 seconds (3.63 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 1.586609e+13, 92297 iterations, 9.91 seconds (3.63 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
#      0     0 1.5866e+13    0  870          - 1.5866e+13      -     -   36s
# INFO:gurobipy.gurobipy:     0     0 1.5866e+13    0  870          - 1.5866e+13      -     -   36s
# H    0     0                    1.588253e+13 1.5866e+13  0.10%     -   36s
# INFO:gurobipy.gurobipy:H    0     0                    1.588253e+13 1.5866e+13  0.10%     -   36s
# H    0     0                    1.588253e+13 1.5866e+13  0.10%     -   38s
# INFO:gurobipy.gurobipy:H    0     0                    1.588253e+13 1.5866e+13  0.10%     -   38s
#      0     0 1.5866e+13    0  220 1.5883e+13 1.5866e+13  0.10%     -   39s
# INFO:gurobipy.gurobipy:     0     0 1.5866e+13    0  220 1.5883e+13 1.5866e+13  0.10%     -   39s
# H    0     0                    1.586733e+13 1.5866e+13  0.01%     -   40s
# INFO:gurobipy.gurobipy:H    0     0                    1.586733e+13 1.5866e+13  0.01%     -   40s
# INFO:gurobipy.gurobipy:
# Cutting planes:
# INFO:gurobipy.gurobipy:Cutting planes:
#   Implied bound: 52
# INFO:gurobipy.gurobipy:  Implied bound: 52
#   MIR: 273
# INFO:gurobipy.gurobipy:  MIR: 273
#   Flow cover: 463
# INFO:gurobipy.gurobipy:  Flow cover: 463
#   Relax-and-lift: 153
# INFO:gurobipy.gurobipy:  Relax-and-lift: 153
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (95546 simplex iterations) in 40.72 seconds (20.01 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (95546 simplex iterations) in 40.72 seconds (20.01 work units)
# Thread count was 12 (of 12 available processors)
# INFO:gurobipy.gurobipy:Thread count was 12 (of 12 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 3: 1.58673e+13 1.58825e+13 1.58825e+13
# INFO:gurobipy.gurobipy:Solution count 3: 1.58673e+13 1.58825e+13 1.58825e+13
# INFO:gurobipy.gurobipy:
# Optimal solution found (tolerance 1.00e-04)
# INFO:gurobipy.gurobipy:Optimal solution found (tolerance 1.00e-04)
# Best objective 1.586732898334e+13, best bound 1.586617739900e+13, gap 0.0073%
# INFO:gurobipy.gurobipy:Best objective 1.586732898334e+13, best bound 1.586617739900e+13, gap 0.0073%
# WARNING:linopy.solvers:Dual values of MILP couldn't be parsed
# Warning: environment still referenced so free is deferred (Continue to use WLS)
# INFO:gurobipy.gurobipy:Warning: environment still referenced so free is deferred (Continue to use WLS)
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 1086240 primals, 0 duals
# Objective: 1.59e+13
# Solver model: available
# Solver message: 2
# ('ok', 'optimal')

# %%
network.generators.p_nom_opt.div(1e3).plot.bar(ylabel="GW", figsize=(8, 3))
# Out:
# <Axes: xlabel='Generator', ylabel='GW'>

# %%
network.generators_t.p['scandinaviaFailure'] = network.generators_t.p['scandinaviaFailure'].clip(lower=0)
network.generators_t.p['GER-Underproduction'] = network.generators_t.p['GER-Underproduction'].clip(lower=0)
network.generators_t.p['GER-CCGT'] = network.generators_t.p['GER-CCGT'].clip(lower=0)
network.generators_t.p['iberianFailure'] = network.generators_t.p['iberianFailure'].clip(lower=0)
network.generators_t.p['polandFailure'] = network.generators_t.p['polandFailure'].clip(lower=0)
network.generators_t.p['FranceOCGT'] = network.generators_t.p['FranceOCGT'].clip(lower=0)
network.generators_t.p['FranceFailure'] = network.generators_t.p['FranceFailure'].clip(lower=0)
network.generators_t.p['FranceOCGT'] = network.generators_t.p['FranceOCGT'].clip(lower=0)
network.generators_t.p['FranceOCGT'] = network.generators_t.p['FranceOCGT'].clip(lower=0)

network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=False, ylabel="GW")
# Out:
# <Axes: xlabel='snapshot', ylabel='GW'>

# %%
network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")
# Out:
# array([<Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>], dtype=object)

# %%
country = "poland"
keepcol = [x for x in network.generators_t.p.columns if x.find(country)==0]
network.generators_t.p[keepcol].resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")

country = "GER"
keepcol = [x for x in network.generators_t.p.columns if x.find(country)==0]
network.generators_t.p[keepcol].resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")

country = "France"
keepcol = [x for x in network.generators_t.p.columns if x.find(country)==0]
network.generators_t.p[keepcol].resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")

country = "iberian"
keepcol = [x for x in network.generators_t.p.columns if x.find(country)==0]
network.generators_t.p[keepcol].resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")

country = "scandinavia"
keepcol = [x for x in network.generators_t.p.columns if x.find(country)==0]
network.generators_t.p[keepcol].resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")
# Out:
# array([<Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>], dtype=object)

# %%
tab_failure = network.generators_t.p[[x for x in network.generators_t.p.columns if x.lower().find("fail")>0]]
tab_failure[tab_failure>0].count()
tab_failure
# Out:
# Generator            scandinaviaFailure  iberianFailure  polandFailure  \
# snapshot
# 1900-01-01 00:00:00                 0.0         7824.48        8049.35
# 1900-01-01 01:00:00                 0.0         6298.61        7819.69
# 1900-01-01 02:00:00                 0.0         5516.36        8771.12
# 1900-01-01 03:00:00                 0.0         4423.13        6649.25
# 1900-01-01 04:00:00                 0.0         3200.82        7437.29
# ...                                 ...             ...            ...
# 1900-12-31 19:00:00                 0.0        12067.60        7604.15
# 1900-12-31 20:00:00                 0.0        13214.19        5829.10
# 1900-12-31 21:00:00                 0.0        12458.55        4497.15
# 1900-12-31 22:00:00                 0.0         9559.94        1074.32
# 1900-12-31 23:00:00                 0.0         8210.34        1590.40
#
# Generator            FranceFailure
# snapshot
# 1900-01-01 00:00:00            0.0
# 1900-01-01 01:00:00            0.0
# 1900-01-01 02:00:00            0.0
# 1900-01-01 03:00:00            0.0
# 1900-01-01 04:00:00            0.0
# ...                            ...
# 1900-12-31 19:00:00            0.0
# 1900-12-31 20:00:00            0.0
# 1900-12-31 21:00:00            0.0
# 1900-12-31 22:00:00            0.0
# 1900-12-31 23:00:00            0.0
#
# [8760 rows x 4 columns]

# %%
network.generators_t.p.div(1e3).resample('W').mean().plot.area(subplots=False, ylabel="GW", stacked=True)
# Out:
# <Axes: xlabel='snapshot', ylabel='GW'>

# %%
network.links_t.p0.resample("W").mean().plot.line(subplots=False, ylabel="GW", stacked=False)
# Out:
# <Axes: xlabel='snapshot', ylabel='GW'>

# %%
network.links_t.p1.resample("W").mean().plot.line(subplots=False, ylabel="GW", stacked=False)
# Out:
# <Axes: xlabel='snapshot', ylabel='GW'>

# %%
tab_max_capa = network.generators_t.p_max_pu.copy()
for asset in tab_max_capa.columns:
    tab_max_capa[asset] = tab_max_capa[asset] * network.generators['p_nom'].loc[asset]

# %%
tab_curtail = tab_max_capa - network.generators_t.p

tab_curtail.resample("W").mean().plot.line(subplots=False, ylabel="GW", stacked=False)
# Out:
# <Axes: xlabel='snapshot', ylabel='GW'>

# %%
tab_curtail_tot = tab_curtail.sum()

# %%
tab_curtail_tot[tab_curtail_tot>0]/1000000
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# d:\donal\Documents\GitHub\athens\Europe 2.ipynb Cell 24 line 3
#       <a href='vscode-notebook-cell:/d%3A/donal/Documents/GitHub/athens/Europe%202.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> tab_curtail_tot[tab_curtail_tot>0]/1000000
# ----> <a href='vscode-notebook-cell:/d%3A/donal/Documents/GitHub/athens/Europe%202.ipynb#X34sZmlsZQ%3D%3D?line=2'>3</a> tab_curtail_tot.resample("W").mean().plot.line(subplots=False, ylabel="GW", stacked=False)
#
# File d:\Serious_Simulation\.conda\lib\site-packages\pandas\core\series.py:5719, in Series.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    5704 @doc(NDFrame.resample, **_shared_doc_kwargs)  # type: ignore[has-type]
#    5705 def resample(
#    5706     self,
#    (...)
#    5717     group_keys: bool = False,
#    5718 ) -> Resampler:
# -> 5719     return super().resample(
#    5720         rule=rule,
#    5721         axis=axis,
#    5722         closed=closed,
#    5723         label=label,
#    5724         convention=convention,
#    5725         kind=kind,
#    5726         on=on,
#    5727         level=level,
#    5728         origin=origin,
#    5729         offset=offset,
#    5730         group_keys=group_keys,
#    5731     )
#
# File d:\Serious_Simulation\.conda\lib\site-packages\pandas\core\generic.py:8888, in NDFrame.resample(self, rule, axis, closed, label, convention, kind, on, level, origin, offset, group_keys)
#    8885 from pandas.core.resample import get_resampler
#    8887 axis = self._get_axis_number(axis)
# -> 8888 return get_resampler(
#    8889     cast("Series | DataFrame", self),
#    8890     freq=rule,
#    8891     label=label,
#    8892     closed=closed,
#    8893     axis=axis,
#    8894     kind=kind,
#    8895     convention=convention,
#    8896     key=on,
#    8897     level=level,
#    8898     origin=origin,
#    8899     offset=offset,
#    8900     group_keys=group_keys,
#    8901 )
#
# File d:\Serious_Simulation\.conda\lib\site-packages\pandas\core\resample.py:1523, in get_resampler(obj, kind, **kwds)
#    1519 """
#    1520 Create a TimeGrouper and return our resampler.
#    1521 """
#    1522 tg = TimeGrouper(**kwds)
# -> 1523 return tg._get_resampler(obj, kind=kind)
#
# File d:\Serious_Simulation\.conda\lib\site-packages\pandas\core\resample.py:1713, in TimeGrouper._get_resampler(self, obj, kind)
#    1704 elif isinstance(ax, TimedeltaIndex):
#    1705     return TimedeltaIndexResampler(
#    1706         obj,
#    1707         timegrouper=self,
#    (...)
#    1710         gpr_index=ax,
#    1711     )
# -> 1713 raise TypeError(
#    1714     "Only valid with DatetimeIndex, "
#    1715     "TimedeltaIndex or PeriodIndex, "
#    1716     f"but got an instance of '{type(ax).__name__}'"
#    1717 )
#
# TypeError: Only valid with DatetimeIndex, TimedeltaIndex or PeriodIndex, but got an instance of 'Index'
