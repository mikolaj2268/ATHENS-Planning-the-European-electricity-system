# %%
# %load_ext autoreload
# %autoreload 2

# %%
import gurobipy
# %pip install pypsa[highs] "xarray>=2023.8.0" Cartopy highspy
# Out:
# Requirement already satisfied: pypsa[highs] in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (0.25.2)
# Requirement already satisfied: xarray>=2023.8.0 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (2023.11.0)
# Requirement already satisfied: Cartopy in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (0.22.0)
# Requirement already satisfied: highspy in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (1.5.3)
# WARNING: pypsa 0.25.2 does not provide the extra 'highs'
# Requirement already satisfied: scipy in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (1.10.0)
# Requirement already satisfied: deprecation in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (2.1.0)
# Requirement already satisfied: numexpr<=2.8.4 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (2.8.4)
# Requirement already satisfied: netcdf4 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (1.6.2)
# Requirement already satisfied: matplotlib in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (3.7.0)
# Requirement already satisfied: tables in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (3.7.0)
# Requirement already satisfied: validators in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (0.22.0)
# Requirement already satisfied: pyomo<6.6.2,>=5.7 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (6.6.1)
# Requirement already satisfied: linopy>=0.2.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (0.3.1)
# Requirement already satisfied: networkx>=1.10 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (2.8.4)
# Requirement already satisfied: numpy in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (1.23.5)
# Requirement already satisfied: pandas<2.1,>=0.24 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pypsa[highs]) (1.5.3)
# Requirement already satisfied: packaging>=21.3 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from xarray>=2023.8.0) (22.0)
# Requirement already satisfied: pyproj>=3.1.0 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from Cartopy) (3.6.1)
# Requirement already satisfied: pyshp>=2.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from Cartopy) (2.3.1)
# Requirement already satisfied: shapely>=1.7 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from Cartopy) (2.0.2)
# Requirement already satisfied: tqdm in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from linopy>=0.2.1->pypsa[highs]) (4.64.1)
# Requirement already satisfied: dask>=0.18.0 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from linopy>=0.2.1->pypsa[highs]) (2022.7.0)
# Requirement already satisfied: bottleneck in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from linopy>=0.2.1->pypsa[highs]) (1.3.5)
# Requirement already satisfied: toolz in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from linopy>=0.2.1->pypsa[highs]) (0.12.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from matplotlib->pypsa[highs]) (1.0.5)
# Requirement already satisfied: pillow>=6.2.0 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from matplotlib->pypsa[highs]) (9.4.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from matplotlib->pypsa[highs]) (4.25.0)
# Requirement already satisfied: cycler>=0.10 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from matplotlib->pypsa[highs]) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from matplotlib->pypsa[highs]) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from matplotlib->pypsa[highs]) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from matplotlib->pypsa[highs]) (3.0.9)
# Requirement already satisfied: pytz>=2020.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pandas<2.1,>=0.24->pypsa[highs]) (2022.7)
# Requirement already satisfied: ply in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pyomo<6.6.2,>=5.7->pypsa[highs]) (3.11)
# Requirement already satisfied: certifi in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from pyproj>=3.1.0->Cartopy) (2023.11.17)
# Requirement already satisfied: cftime in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from netcdf4->pypsa[highs]) (1.6.2)
# Requirement already satisfied: pyyaml>=5.3.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from dask>=0.18.0->linopy>=0.2.1->pypsa[highs]) (6.0)
# Requirement already satisfied: partd>=0.3.10 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from dask>=0.18.0->linopy>=0.2.1->pypsa[highs]) (1.2.0)
# Requirement already satisfied: cloudpickle>=1.1.1 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from dask>=0.18.0->linopy>=0.2.1->pypsa[highs]) (2.0.0)
# Requirement already satisfied: fsspec>=0.6.0 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from dask>=0.18.0->linopy>=0.2.1->pypsa[highs]) (2022.11.0)
# Requirement already satisfied: six>=1.5 in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib->pypsa[highs]) (1.16.0)
# Requirement already satisfied: locket in /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages (from partd>=0.3.10->dask>=0.18.0->linopy>=0.2.1->pypsa[highs]) (1.0.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from gurobipy import *
from add_country import *

# %%
import pypsa
import pandas as pd
from dataclasses import dataclass

# %%
add_scandinavia(network, climatic_year, time_horizon_in_hours)
# Out:
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:The bus name `Curtailment` given for bus of Load `scandinaviaCurtailment-load` does not appear in network.buses

# %%
add_germany(network, climatic_year, time_horizon_in_hours)
# Out:
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_min_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_max_pu, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute max_hours, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute efficiency, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute cyclic_state_of_charge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_discharge, ignoring this passed value.
# WARNING:pypsa.components:Store has no attribute p_nom_charge, ignoring this passed value.
# WARNING:pypsa.components:The bus name `Curtailment` given for bus of Load `germanyCurtailment-load` does not appear in network.buses

# %%
network.generators
# Out:
# attribute                          bus control type     p_nom  \
# Generator
# scandinaviaFossils         Scandinavia      PQ         5000.0
# scandinaviaBioEnergies     Scandinavia      PQ        11000.0
# scandinaviaHydroelectric   Scandinavia      PQ        57000.0
# scandinaviaWind_on_shore   Scandinavia      PQ        43000.0
# scandinaviaWind_off_shore  Scandinavia      PQ        17000.0
# scandinaviaNuclear         Scandinavia      PQ        11000.0
# scandinaviaSolar           Scandinavia      PQ        19000.0
# scandinaviaFailure         Scandinavia      PQ       100000.0
# germanyFossils                 Germany      PQ         5000.0
# germanyBioEnergies             Germany      PQ        11000.0
# germanyHydroelectric           Germany      PQ        57000.0
# germanyWind_on_shore           Germany      PQ        43000.0
# germanyWind_off_shore          Germany      PQ        17000.0
# germanyNuclear                 Germany      PQ        11000.0
# germanySolar                   Germany      PQ        19000.0
# germanyFailure                 Germany      PQ       100000.0
#
# attribute                  p_nom_extendable  p_nom_min  p_nom_max  p_min_pu  \
# Generator
# scandinaviaFossils                    False        0.0        inf       0.0
# scandinaviaBioEnergies                False        0.0        inf       0.0
# scandinaviaHydroelectric              False        0.0        inf       0.0
# scandinaviaWind_on_shore              False        0.0        inf       0.0
# scandinaviaWind_off_shore             False        0.0        inf       0.0
# scandinaviaNuclear                    False        0.0        inf       0.0
# scandinaviaSolar                      False        0.0        inf       0.0
# scandinaviaFailure                    False        0.0        inf       0.0
# germanyFossils                        False        0.0        inf       0.0
# germanyBioEnergies                    False        0.0        inf       0.0
# germanyHydroelectric                  False        0.0        inf       0.0
# germanyWind_on_shore                  False        0.0        inf       0.0
# germanyWind_off_shore                 False        0.0        inf       0.0
# germanyNuclear                        False        0.0        inf       0.0
# germanySolar                          False        0.0        inf       0.0
# germanyFailure                        False        0.0        inf       0.0
#
# attribute                  p_max_pu  p_set  ...  min_up_time  min_down_time  \
# Generator                                   ...
# scandinaviaFossils              1.0    0.0  ...            1              1
# scandinaviaBioEnergies          1.0    0.0  ...            1              1
# scandinaviaHydroelectric        1.0    0.0  ...            1              1
# scandinaviaWind_on_shore        1.0    0.0  ...            1              1
# scandinaviaWind_off_shore       1.0    0.0  ...            1              1
# scandinaviaNuclear              1.0    0.0  ...           24             24
# scandinaviaSolar                1.0    0.0  ...            1              1
# scandinaviaFailure              1.0    0.0  ...            1              1
# germanyFossils                  1.0    0.0  ...            1              1
# germanyBioEnergies              1.0    0.0  ...            1              1
# germanyHydroelectric            1.0    0.0  ...            1              1
# germanyWind_on_shore            1.0    0.0  ...            1              1
# germanyWind_off_shore           1.0    0.0  ...            1              1
# germanyNuclear                  1.0    0.0  ...           24             24
# germanySolar                    1.0    0.0  ...            1              1
# germanyFailure                  1.0    0.0  ...            1              1
#
# attribute                 up_time_before  down_time_before  ramp_limit_up  \
# Generator
# scandinaviaFossils                     1                 0            NaN
# scandinaviaBioEnergies                 1                 0            NaN
# scandinaviaHydroelectric               1                 0            NaN
# scandinaviaWind_on_shore               1                 0            NaN
# scandinaviaWind_off_shore              1                 0            NaN
# scandinaviaNuclear                     1                 0            NaN
# scandinaviaSolar                       1                 0            NaN
# scandinaviaFailure                     1                 0            NaN
# germanyFossils                         1                 0            NaN
# germanyBioEnergies                     1                 0            NaN
# germanyHydroelectric                   1                 0            NaN
# germanyWind_on_shore                   1                 0            NaN
# germanyWind_off_shore                  1                 0            NaN
# germanyNuclear                         1                 0            NaN
# germanySolar                           1                 0            NaN
# germanyFailure                         1                 0            NaN
#
# attribute                  ramp_limit_down  ramp_limit_start_up  \
# Generator
# scandinaviaFossils                     NaN                  1.0
# scandinaviaBioEnergies                 NaN                  1.0
# scandinaviaHydroelectric               NaN                  1.0
# scandinaviaWind_on_shore               NaN                  1.0
# scandinaviaWind_off_shore              NaN                  1.0
# scandinaviaNuclear                     NaN                  1.0
# scandinaviaSolar                       NaN                  1.0
# scandinaviaFailure                     NaN                  1.0
# germanyFossils                         NaN                  1.0
# germanyBioEnergies                     NaN                  1.0
# germanyHydroelectric                   NaN                  1.0
# germanyWind_on_shore                   NaN                  1.0
# germanyWind_off_shore                  NaN                  1.0
# germanyNuclear                         NaN                  1.0
# germanySolar                           NaN                  1.0
# germanyFailure                         NaN                  1.0
#
# attribute                  ramp_limit_shut_down  weight  p_nom_opt
# Generator
# scandinaviaFossils                          1.0     1.0        0.0
# scandinaviaBioEnergies                      1.0     1.0        0.0
# scandinaviaHydroelectric                    1.0     1.0        0.0
# scandinaviaWind_on_shore                    1.0     1.0        0.0
# scandinaviaWind_off_shore                   1.0     1.0        0.0
# scandinaviaNuclear                          1.0     1.0        0.0
# scandinaviaSolar                            1.0     1.0        0.0
# scandinaviaFailure                          1.0     1.0        0.0
# germanyFossils                              1.0     1.0        0.0
# germanyBioEnergies                          1.0     1.0        0.0
# germanyHydroelectric                        1.0     1.0        0.0
# germanyWind_on_shore                        1.0     1.0        0.0
# germanyWind_off_shore                       1.0     1.0        0.0
# germanyNuclear                              1.0     1.0        0.0
# germanySolar                                1.0     1.0        0.0
# germanyFailure                              1.0     1.0        0.0
#
# [16 rows x 33 columns]

# %%
network
# Out:
# PyPSA Network
# Components:
#  - Bus: 2
#  - Generator: 16
#  - Load: 4
#  - Store: 8
# Snapshots: 8760

# %%
links_list = [
    {"name" : "Link_SCA_Curtailment", "bus0" : "Scandinavia", "bus1" : "Curtailment", "p_nom" : 700000, "efficiency" : 0.95},
    {"name" : "Link_SCA_Germany", "bus0":"Scandinavia", "bus1":"Germany", "p_nom":7415, "efficiency":0.95},
    {"name" : "Link_SCA_Poland", "bus0":"Scandinavia", "bus1":"Poland", "p_nom":600, "efficiency":0.95},
    #{"name" : "Link_SCA_Benelux", "bus0":"Scandinavia", "bus1":"Benelux", "p_nom":1400, "efficiency":0.95},
    #{"name" : "Link_Benelux_SCA", "bus0":"Benelux", "bus1":"Scandinavia", "p_nom":1400, "efficiency":0.95},
    {"name" : "Link_Poland_SCA", "bus0":"Poland", "bus1":"Scandinavia", "p_nom":0, "efficiency":0.95},
    {"name" : "Link_Germany_SCA", "bus0":"Germany", "bus1":"Scandinavia", "p_nom":2000, "efficiency":0.95},
    {"name" : "Link_France_Germany", "bus0":"France", "bus1":"Germany", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_France", "bus0":"Germany", "bus1":"France", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_Poland", "bus0":"Germany", "bus1":"Poland", "p_nom":3400, "efficiency":0.95},
    {"name" : "Link_Poland_Germany", "bus0":"Poland", "bus1":"Germany", "p_nom":3400, "efficiency":0.95},
    #{"name" : "Link_Germany_Benelux", "bus0":"Germany", "bus1":"Benelux", "p_nom":9300, "efficiency":0.95},
    #{"name" : "Link_Benelux_Germany", "bus0":"Benelux", "bus1":"Germany", "p_nom":9300, "efficiency":0.95},
    #{"name" : "Link_Benelux_France", "bus0":"Benelux", "bus1":"France", "p_nom":4680, "efficiency":0.95},
    #{"name" : "Link_France_Benelux", "bus0":"France", "bus1":"Benelux", "p_nom":4680, "efficiency":0.95},
    {"name" : "Link_France_Iberian", "bus0":"France", "bus1":"Iberian", "p_nom":5000, "efficiency":0.95},
    {"name" : "Link_Iberian_France", "bus0":"Iberian", "bus1":"France", "p_nom":5000, "efficiency":0.95},
]

for links in links_list:
    network.add("Link", **links,)
# Out:
# WARNING:pypsa.components:The bus name `Curtailment` given for bus1 of Link `Link_SCA_Curtailment` does not appear in network.buses
# WARNING:pypsa.components:The bus name `Poland` given for bus1 of Link `Link_SCA_Poland` does not appear in network.buses
# WARNING:pypsa.components:The bus name `Poland` given for bus0 of Link `Link_Poland_SCA` does not appear in network.buses
# WARNING:pypsa.components:The bus name `France` given for bus0 of Link `Link_France_Germany` does not appear in network.buses
# WARNING:pypsa.components:The bus name `France` given for bus1 of Link `Link_Germany_France` does not appear in network.buses
# WARNING:pypsa.components:The bus name `Poland` given for bus1 of Link `Link_Germany_Poland` does not appear in network.buses
# WARNING:pypsa.components:The bus name `Poland` given for bus0 of Link `Link_Poland_Germany` does not appear in network.buses
# WARNING:pypsa.components:The bus name `France` given for bus0 of Link `Link_France_Iberian` does not appear in network.buses
# WARNING:pypsa.components:The bus name `Iberian` given for bus1 of Link `Link_France_Iberian` does not appear in network.buses
# WARNING:pypsa.components:The bus name `Iberian` given for bus0 of Link `Link_Iberian_France` does not appear in network.buses
# WARNING:pypsa.components:The bus name `France` given for bus1 of Link `Link_Iberian_France` does not appear in network.buses

# %%
network.plot(
    title="European Electricity Network",
    color_geomap=True,
    jitter=0.3,
)
# Out:
# (<matplotlib.collections.PatchCollection at 0x7feb0ad12620>,
#  <matplotlib.collections.LineCollection at 0x7feb0ad12e30>)
# /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning:
#
# facecolor will have no effect as it has been defined as "never".

# %%
result = network.optimize(solver_name="gurobi")
print(result)
# Out:
# WARNING:pypsa.components:The following loads have bus which are not defined:
# Index(['scandinaviaCurtailment-load', 'germanyCurtailment-load'], dtype='object', name='Load')
# WARNING:pypsa.components:The following links have bus0 which are not defined:
# Index(['Link_Poland_SCA', 'Link_France_Germany', 'Link_Poland_Germany',
#        'Link_France_Iberian', 'Link_Iberian_France'],
#       dtype='object', name='Link')
# WARNING:pypsa.components:The following links have bus1 which are not defined:
# Index(['Link_SCA_Curtailment', 'Link_SCA_Poland', 'Link_Germany_France',
#        'Link_Germany_Poland', 'Link_France_Iberian', 'Link_Iberian_France'],
#       dtype='object', name='Link')
# WARNING:pypsa.components:The following loads have bus which are not defined:
# Index(['scandinaviaCurtailment-load', 'germanyCurtailment-load'], dtype='object', name='Load')
# WARNING:pypsa.components:The following links have bus0 which are not defined:
# Index(['Link_Poland_SCA', 'Link_France_Germany', 'Link_Poland_Germany',
#        'Link_France_Iberian', 'Link_Iberian_France'],
#       dtype='object', name='Link')
# WARNING:pypsa.components:The following links have bus1 which are not defined:
# Index(['Link_SCA_Curtailment', 'Link_SCA_Poland', 'Link_Germany_France',
#        'Link_Germany_Poland', 'Link_France_Iberian', 'Link_Iberian_France'],
#       dtype='object', name='Link')
# INFO:linopy.model: Solve problem using Gurobi solver
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-21
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-11-21
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|████████████████████████████████████████████| 15/15 [00:08<00:00,  1.86it/s]
# Writing continuous variables.: 100%|█████████████████████████████████████| 4/4 [00:00<00:00,  5.08it/s]
# Writing binary variables.: 100%|█████████████████████████████████████████| 3/3 [00:00<00:00, 15.29it/s]
# INFO:linopy.io: Writing time: 9.3s
# Read LP format model from file /private/var/folders/ms/4_rjwj4n1h1gg3k7zdvmsv5m0000gn/T/linopy-problem-sx7a7et9.lp
# INFO:gurobipy.gurobipy:Read LP format model from file /private/var/folders/ms/4_rjwj4n1h1gg3k7zdvmsv5m0000gn/T/linopy-problem-sx7a7et9.lp
# Reading time = 2.63 seconds
# INFO:gurobipy.gurobipy:Reading time = 2.63 seconds
# obj: 1051226 rows, 639480 columns, 2898434 nonzeros
# INFO:gurobipy.gurobipy:obj: 1051226 rows, 639480 columns, 2898434 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-8259U CPU @ 2.30GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-8259U CPU @ 2.30GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy.gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 1051226 rows, 639480 columns and 2898434 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 1051226 rows, 639480 columns and 2898434 nonzeros
# Model fingerprint: 0x6ffde91a
# INFO:gurobipy.gurobipy:Model fingerprint: 0x6ffde91a
# Variable types: 376680 continuous, 262800 integer (262800 binary)
# INFO:gurobipy.gurobipy:Variable types: 376680 continuous, 262800 integer (262800 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [9e-01, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [9e-01, 1e+05]
#   Objective range  [5e+00, 1e+05]
# INFO:gurobipy.gurobipy:  Objective range  [5e+00, 1e+05]
#   Bounds range     [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+00, 7e+05]
# Presolve removed 975480 rows and 572276 columns (presolve time = 5s) ...
# INFO:gurobipy.gurobipy:Presolve removed 975480 rows and 572276 columns (presolve time = 5s) ...
# Presolve removed 975602 rows and 639476 columns (presolve time = 16s) ...
# INFO:gurobipy.gurobipy:Presolve removed 975602 rows and 639476 columns (presolve time = 16s) ...
# Presolve removed 1051224 rows and 639476 columns
# INFO:gurobipy.gurobipy:Presolve removed 1051224 rows and 639476 columns
# Presolve time: 16.17s
# INFO:gurobipy.gurobipy:Presolve time: 16.17s
# Presolved: 2 rows, 4 columns, 5 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 2 rows, 4 columns, 5 nonzeros
# Variable types: 3 continuous, 1 integer (1 binary)
# INFO:gurobipy.gurobipy:Variable types: 3 continuous, 1 integer (1 binary)
# INFO:gurobipy.gurobipy:
# Root simplex log...
# INFO:gurobipy.gurobipy:Root simplex log...
# INFO:gurobipy.gurobipy:
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# INFO:gurobipy.gurobipy:Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    7.0539052e+10   1.447368e+03   0.000000e+00     17s
# INFO:gurobipy.gurobipy:       0    7.0539052e+10   1.447368e+03   0.000000e+00     17s
#        1    7.0539107e+10   0.000000e+00   0.000000e+00     17s
# INFO:gurobipy.gurobipy:       1    7.0539107e+10   0.000000e+00   0.000000e+00     17s
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 7.053911e+10, 1 iterations, 0.01 seconds (0.00 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 7.053911e+10, 1 iterations, 0.01 seconds (0.00 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
# *    0     0               0    7.053911e+10 7.0539e+10  0.00%     -   17s
# INFO:gurobipy.gurobipy:*    0     0               0    7.053911e+10 7.0539e+10  0.00%     -   17s
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (1 simplex iterations) in 17.14 seconds (17.05 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (1 simplex iterations) in 17.14 seconds (17.05 work units)
# Thread count was 8 (of 8 available processors)
# INFO:gurobipy.gurobipy:Thread count was 8 (of 8 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 1: 7.05391e+10
# INFO:gurobipy.gurobipy:Solution count 1: 7.05391e+10
# INFO:gurobipy.gurobipy:
# Optimal solution found (tolerance 1.00e-04)
# INFO:gurobipy.gurobipy:Optimal solution found (tolerance 1.00e-04)
# Best objective 7.053910673400e+10, best bound 7.053910673384e+10, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 7.053910673400e+10, best bound 7.053910673384e+10, gap 0.0000%
# WARNING:linopy.solvers:Dual values of MILP couldn't be parsed
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 639480 primals, 0 duals
# Objective: 7.05e+10
# Solver model: available
# Solver message: 2
# ('ok', 'optimal')

# %%
network.generators.p_nom_opt.div(1e3).plot.bar(ylabel="GW", figsize=(8, 3))
# Out:
# <Axes: xlabel='Generator', ylabel='GW'>

# %%
network.generators_t.p['scandinaviaFailure'] = network.generators_t.p['scandinaviaFailure'].clip(lower=0)
network.generators_t.p['germanyFailure'] = network.generators_t.p['germanyFailure'].clip(lower=0)

network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=False, ylabel="GW")
# Out:
# <Axes: xlabel='snapshot', ylabel='GW'>

# %%
network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")
# Out:
# array([<Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>], dtype=object)

# %%
countries = {"Scandinavia", "Germany", "Poland", "France", "Iberian"}
#for country in countries:
full_demand = pd.read_csv(f"./data/demand_2030_Scandinavia.csv", sep=";", index_col=1, parse_dates=True).groupby(pd.Grouper(key="climatic_year"))
full_wind_on_shore= pd.read_csv("./data/capa_factor_2030_scandinavia_onshore.csv", index_col=1, parse_dates=True, sep=";").groupby(pd.Grouper(key="climatic_year"))
full_solar = pd.read_csv("./data/capa_factor_2030_scandinavia_solar.csv", index_col=1, parse_dates=True, sep=";").groupby(pd.Grouper(key="climatic_year"))
full_wind_off_shore = pd.read_csv("./data/capa_factor_2030_scandinavia_offshore.csv", index_col=1, parse_dates=True, sep=";").groupby(pd.Grouper(key="climatic_year"))

# %%
climatic_year = 2000
time_horizon_in_hours = 365 * 24

# %%
demand = full_demand.get_group(climatic_year)
solar = full_solar.get_group(climatic_year)
wind_on_shore = full_wind_on_shore.get_group(climatic_year)
wind_off_shore = full_wind_off_shore.get_group(climatic_year)

# %%
network = pypsa.Network(snapshots=demand.index[0:time_horizon_in_hours])

# %%
network.add("Bus", name="Scandinavia", x=15.255119, y=60.128161)
network.add("Bus", name="Curtailment", x=10, y=65)
network.add("Bus", name="Poland", x=21.0117800, y=52.2297700)
network.add("Bus", name="Germany", x=13.4105300, y=52.5243700)
#network.add("Bus", name="Benelux", x=4.3487800, y=50.8504500)
network.add("Bus", name="France", x=2.3488000, y=48.8534100)
network.add("Bus", name="Iberian", x=-3.7025600, y=40.4165000)

# %%
@dataclass
class Carriers:
    Battery = 0
    Biomass = 230
    Coal = 760
    Gas = 370
    Oil = 406
    Hydrogen = 490
    Hydro = 24
    Nuclear = 12
    Pumped = 0
    Reservoir = 0
    Solar = 45
    Wind = 11

# %%
for name, co2_emission in Carriers().__dict__.items():
    network.add("Carrier", name=name, co2_emissions=co2_emission)

# %%
#???
coal_marginal_costs = 160
gas_marginal_costs = 120
oil_marginal_costs = 100
nuclear_marginal_costs = 10
hydro_marginal_costs = 5
wind_marginal_costs = 5
solar_marginal_costs = 5
biomass_marginal_costs = 5


reservoir_max_hours = 365*24
pumped_max_hours = 100
battery_max_hours = 200
H2_max_hours = 300



#coal_marginal_costs = 128 / 7 / 0.37 
#gas_marginal_costs = 2.65 * 26.4 * 0.75 / 14.9 / 0.5
#oil_marginal_costs = 73 * 0.119 / 12.5 / 0.40

# %%
generators = [
    #{"name": "Coal", "carrier": "Coal", "p_nom": 2112, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": coal_marginal_costs, "efficiency": 0.37, "committable": True, "min_up_time": 1, "min_down_time": 1},
    #{"name": "Gas", "carrier": "Gas", "p_nom": 2640, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": gas_marginal_costs, "efficiency": 0.5,
    # "committable": True, "min_up_time": 1, "min_down_time": 1},
    #{"name": "Oil", "carrier": "Oil", "p_nom": 0, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": oil_marginal_costs, "efficiency": 0.4,
    # "committable": True, "min_up_time": 1, "min_down_time": 1},
    {"name": "Fossils", "carrier": "Fossils", "p_nom": 5000, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": gas_marginal_costs, "efficiency": 0.4,
     "committable": True, "min_up_time": 1, "min_down_time": 1},
    {"name": "BioEnergies", "carrier": "BioEnergies", "p_nom":11000, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": biomass_marginal_costs, "efficiency": 0.5, 
     "committable": True, "min_up_time": 1, "min_down_time": 1},
    {"name": "Hydroelectric", "carrier":"Hydro", "p_nom": 57000, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": hydro_marginal_costs, "efficiency": 1, "committable": True,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Wind_on_shore", "carrier": "Wind_on_shore", "p_nom": 43000, "p_min_pu":wind_on_shore.value, "p_max_pu": wind_on_shore.value, "marginal_cost": wind_marginal_costs, "efficiency":1, "committable": False,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Wind_off_shore", "carrier": "Wind_off_shore", "p_nom": 17000, "p_min_pu":wind_off_shore.value, "p_max_pu": wind_off_shore.value, "marginal_cost": wind_marginal_costs, "efficiency":1, "committable": False,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Nuclear", "carrier": "Nuclear", "p_nom": 11000, "p_min_pu":0, "p_max_pu": 1, "marginal_cost": nuclear_marginal_costs, "efficiency":1, "committable": True,
     "min_up_time": 24, "min_down_time": 24},
    {"name": "Solar", "carrier": "Solar", "p_nom": 19000, "p_min_pu":solar.value, "p_max_pu": solar.value, "marginal_cost": solar_marginal_costs, "efficiency":1, "committable": False,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Failure", "carrier": "Failure", "p_nom": 100000, "p_min_pu":0, "p_max_pu": 1, "marginal_cost": 100000, "efficiency":1, "committable": True,
     "min_up_time": 1, "min_down_time": 1},
    #{"name": "Curtailment", "carrier": "Curtailment", "p_nom": 100000, "p_min_pu":1, "p_max_pu": 1, "marginal_cost": 0, "efficiency":1, "committable": True,
     #"min_up_time": 1, "min_down_time": 1},
]

fictive_generator = [
    {"name": "Curtailment", "carrier": "Curtailment", "p_nom": 100000, "p_min_pu":0, "p_max_pu": 1, "marginal_cost": 0.0001, "efficiency":1, "committable": True,
     "min_up_time": 1, "min_down_time": 1}
]


storage_units = [
        {"name": "Reservoir", "carrier": "Reservoir", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": reservoir_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" : 100, "p_nom_charge" : 100},
        {"name": "Pumped", "carrier": "Pumped", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": pumped_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" : 100, "p_nom_charge" : 100},
        {"name": "Battery", "carrier": "Battery", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": battery_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" : 100, "p_nom_charge" : 100},
        {"name": "H2", "carrier": "H2", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": H2_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" :100, "p_nom_charge" : 100},
]

# %%
for generator in generators:
    network.add("Generator", bus="Scandinavia", **generator,)
    
for generator in fictive_generator:
    network.add("Generator", bus="Curtailment", **generator,)
for storage in storage_units:
    network.add("Store", bus="Scandinavia", **storage,)

# %%
#'carrier', "AC" ?? 

loads = [
    {"name": "Scandinavia-load", "bus": "Scandinavia", "carrier": "AC","p_set": demand[0:time_horizon_in_hours]["value"].values*1},
    {"name": "Curtailment-load", "bus": "Curtailment", "carrier": "AC","p_set": 10000},
]

# %%
for load in loads:
    network.add("Load", **load)

# %%
links_list = [
    {"name" : "Link_SCA_Curtailment", "bus0" : "Scandinavia", "bus1" : "Curtailment", "p_nom" : 700000, "efficiency" : 0.95},
    {"name" : "Link_SCA_Germany", "bus0":"Scandinavia", "bus1":"Germany", "p_nom":7415, "efficiency":0.95},
    {"name" : "Link_SCA_Poland", "bus0":"Scandinavia", "bus1":"Poland", "p_nom":600, "efficiency":0.95},
    #{"name" : "Link_SCA_Benelux", "bus0":"Scandinavia", "bus1":"Benelux", "p_nom":1400, "efficiency":0.95},
    #{"name" : "Link_Benelux_SCA", "bus0":"Benelux", "bus1":"Scandinavia", "p_nom":1400, "efficiency":0.95},
    {"name" : "Link_Poland_SCA", "bus0":"Poland", "bus1":"Scandinavia", "p_nom":0, "efficiency":0.95},
    {"name" : "Link_Germany_SCA", "bus0":"Germany", "bus1":"Scandinavia", "p_nom":2000, "efficiency":0.95},
    {"name" : "Link_France_Germany", "bus0":"France", "bus1":"Germany", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_France", "bus0":"Germany", "bus1":"France", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_Poland", "bus0":"Germany", "bus1":"Poland", "p_nom":3400, "efficiency":0.95},
    {"name" : "Link_Poland_Germany", "bus0":"Poland", "bus1":"Germany", "p_nom":3400, "efficiency":0.95},
    #{"name" : "Link_Germany_Benelux", "bus0":"Germany", "bus1":"Benelux", "p_nom":9300, "efficiency":0.95},
    #{"name" : "Link_Benelux_Germany", "bus0":"Benelux", "bus1":"Germany", "p_nom":9300, "efficiency":0.95},
    #{"name" : "Link_Benelux_France", "bus0":"Benelux", "bus1":"France", "p_nom":4680, "efficiency":0.95},
    #{"name" : "Link_France_Benelux", "bus0":"France", "bus1":"Benelux", "p_nom":4680, "efficiency":0.95},
    {"name" : "Link_France_Iberian", "bus0":"France", "bus1":"Iberian", "p_nom":5000, "efficiency":0.95},
    {"name" : "Link_Iberian_France", "bus0":"Iberian", "bus1":"France", "p_nom":5000, "efficiency":0.95},
]

for links in links_list:
    network.add("Link", **links,)

#network.add("Link",
#            "Link_SCA_Curtailment",  # Unique identifier for the link
#            bus0="Scandinavia",    # Name of the first country/bus
##            bus1="Curtailment",    # Name of the second country/bus
 #           p_nom=700000,           # Transmission capacity in MW (adjust as needed)
 #           efficiency=0.95,      # Transmission efficiency (adjust as needed)
 #          )

# %%
network
# Out:
# PyPSA Network
# Components:
#  - Bus: 6
#  - Link: 11
# Snapshots: 8760

# %%
network.plot(
    title="European Electricity Network",
    color_geomap=True,
    jitter=0.3,
)
# Out:
# (<matplotlib.collections.PatchCollection at 0x7fc1722f1b70>,
#  <matplotlib.collections.LineCollection at 0x7fc1722f27a0>)
# /Users/alexandrerebiere/Documents/anaconda3/lib/python3.10/site-packages/cartopy/mpl/style.py:76: UserWarning:
#
# facecolor will have no effect as it has been defined as "never".

# %%
result = network.optimize(solver_name="gurobi")
print(result)
# Out:
# INFO:linopy.model: Solve problem using Gurobi solver
# Set parameter Username
# INFO:gurobipy.gurobipy:Set parameter Username
# Academic license - for non-commercial use only - expires 2024-11-21
# INFO:gurobipy.gurobipy:Academic license - for non-commercial use only - expires 2024-11-21
# INFO:linopy.io:Writing objective.
# Writing constraints.: 100%|████████████████████████████████████████████| 12/12 [00:03<00:00,  3.01it/s]
# Writing continuous variables.: 100%|█████████████████████████████████████| 2/2 [00:00<00:00,  6.02it/s]
# Writing binary variables.: 100%|█████████████████████████████████████████| 3/3 [00:00<00:00, 19.39it/s]
# INFO:linopy.io: Writing time: 4.63s
# Read LP format model from file /private/var/folders/ms/4_rjwj4n1h1gg3k7zdvmsv5m0000gn/T/linopy-problem-1aqhx6hs.lp
# INFO:gurobipy.gurobipy:Read LP format model from file /private/var/folders/ms/4_rjwj4n1h1gg3k7zdvmsv5m0000gn/T/linopy-problem-1aqhx6hs.lp
# Reading time = 1.28 seconds
# INFO:gurobipy.gurobipy:Reading time = 1.28 seconds
# obj: 534371 rows, 297840 columns, 1462355 nonzeros
# INFO:gurobipy.gurobipy:obj: 534371 rows, 297840 columns, 1462355 nonzeros
# Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:Gurobi Optimizer version 10.0.3 build v10.0.3rc0 (mac64[x86])
# INFO:gurobipy.gurobipy:
# CPU model: Intel(R) Core(TM) i5-8259U CPU @ 2.30GHz
# INFO:gurobipy.gurobipy:CPU model: Intel(R) Core(TM) i5-8259U CPU @ 2.30GHz
# Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy.gurobipy:Thread count: 4 physical cores, 8 logical processors, using up to 8 threads
# INFO:gurobipy.gurobipy:
# Optimize a model with 534371 rows, 297840 columns and 1462355 nonzeros
# INFO:gurobipy.gurobipy:Optimize a model with 534371 rows, 297840 columns and 1462355 nonzeros
# Model fingerprint: 0x5fdb6deb
# INFO:gurobipy.gurobipy:Model fingerprint: 0x5fdb6deb
# Variable types: 140160 continuous, 157680 integer (157680 binary)
# INFO:gurobipy.gurobipy:Variable types: 140160 continuous, 157680 integer (157680 binary)
# Coefficient statistics:
# INFO:gurobipy.gurobipy:Coefficient statistics:
#   Matrix range     [9e-01, 1e+05]
# INFO:gurobipy.gurobipy:  Matrix range     [9e-01, 1e+05]
#   Objective range  [1e-04, 1e+05]
# INFO:gurobipy.gurobipy:  Objective range  [1e-04, 1e+05]
#   Bounds range     [1e+00, 1e+00]
# INFO:gurobipy.gurobipy:  Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 7e+05]
# INFO:gurobipy.gurobipy:  RHS range        [1e+00, 7e+05]
# Presolve removed 498215 rows and 297835 columns (presolve time = 6s) ...
# INFO:gurobipy.gurobipy:Presolve removed 498215 rows and 297835 columns (presolve time = 6s) ...
# Presolve removed 534369 rows and 297835 columns
# INFO:gurobipy.gurobipy:Presolve removed 534369 rows and 297835 columns
# Presolve time: 5.91s
# INFO:gurobipy.gurobipy:Presolve time: 5.91s
# Presolved: 2 rows, 5 columns, 6 nonzeros
# INFO:gurobipy.gurobipy:Presolved: 2 rows, 5 columns, 6 nonzeros
# Variable types: 4 continuous, 1 integer (1 binary)
# INFO:gurobipy.gurobipy:Variable types: 4 continuous, 1 integer (1 binary)
# INFO:gurobipy.gurobipy:
# Root simplex log...
# INFO:gurobipy.gurobipy:Root simplex log...
# INFO:gurobipy.gurobipy:
# Iteration    Objective       Primal Inf.    Dual Inf.      Time
# INFO:gurobipy.gurobipy:Iteration    Objective       Primal Inf.    Dual Inf.      Time
#        0    3.3077589e+09   2.612500e+03   0.000000e+00      6s
# INFO:gurobipy.gurobipy:       0    3.3077589e+09   2.612500e+03   0.000000e+00      6s
#        1    3.3078139e+09   0.000000e+00   0.000000e+00      6s
# INFO:gurobipy.gurobipy:       1    3.3078139e+09   0.000000e+00   0.000000e+00      6s
# INFO:gurobipy.gurobipy:
# Root relaxation: objective 3.307814e+09, 1 iterations, 0.02 seconds (0.00 work units)
# INFO:gurobipy.gurobipy:Root relaxation: objective 3.307814e+09, 1 iterations, 0.02 seconds (0.00 work units)
# INFO:gurobipy.gurobipy:
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
# INFO:gurobipy.gurobipy:    Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy: Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
# INFO:gurobipy.gurobipy:
# *    0     0               0    3.307814e+09 3.3078e+09  0.00%     -    6s
# INFO:gurobipy.gurobipy:*    0     0               0    3.307814e+09 3.3078e+09  0.00%     -    6s
# INFO:gurobipy.gurobipy:
# Explored 1 nodes (1 simplex iterations) in 6.33 seconds (7.65 work units)
# INFO:gurobipy.gurobipy:Explored 1 nodes (1 simplex iterations) in 6.33 seconds (7.65 work units)
# Thread count was 8 (of 8 available processors)
# INFO:gurobipy.gurobipy:Thread count was 8 (of 8 available processors)
# INFO:gurobipy.gurobipy:
# Solution count 1: 3.30781e+09
# INFO:gurobipy.gurobipy:Solution count 1: 3.30781e+09
# No other solutions better than 3.30781e+09
# INFO:gurobipy.gurobipy:No other solutions better than 3.30781e+09
# INFO:gurobipy.gurobipy:
# Optimal solution found (tolerance 1.00e-04)
# INFO:gurobipy.gurobipy:Optimal solution found (tolerance 1.00e-04)
# Best objective 3.307813861849e+09, best bound 3.307813861849e+09, gap 0.0000%
# INFO:gurobipy.gurobipy:Best objective 3.307813861849e+09, best bound 3.307813861849e+09, gap 0.0000%
# WARNING:linopy.solvers:Dual values of MILP couldn't be parsed
# INFO:linopy.constants: Optimization successful:
# Status: ok
# Termination condition: optimal
# Solution: 297840 primals, 0 duals
# Objective: 3.31e+09
# Solver model: available
# Solver message: 2
# ('ok', 'optimal')

# %%
network.generators.p_nom_opt.div(1e3).plot.bar(ylabel="GW", figsize=(8, 3))
# Out:
# <Axes: xlabel='Generator', ylabel='GW'>

# %%
network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=False, ylabel="GW")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=False, ylabel="GW")
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_core.py:1557, in PlotAccessor.area(self, x, y, **kwargs)
#    1486 def area(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1487     """
#    1488     Draw a stacked area plot.
#    1489
#    (...)
#    1555         >>> ax = df.plot.area(x='day')
#    1556     """
# -> 1557     return self(kind="area", x=x, y=y, **kwargs)
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1382, in LinePlot._make_plot(self)
#    1379 label = self._mark_right_label(label, index=i)
#    1380 kwds["label"] = label
# -> 1382 newlines = plotf(
#    1383     ax,
#    1384     x,
#    1385     y,
#    1386     style=style,
#    1387     column_num=i,
#    1388     stacking_id=stacking_id,
#    1389     is_errorbar=is_errorbar,
#    1390     **kwds,
#    1391 )
#    1392 self._append_legend_handles_labels(newlines[0], label)
#    1394 if self._is_ts_plot():
#    1395
#    1396     # reset of xlim should be used for ts data
#    1397     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1431, in LinePlot._ts_plot(self, ax, x, data, style, **kwds)
#    1428     decorate_axes(ax.right_ax, freq, kwds)
#    1429 ax._plot_data.append((data, self._kind, kwds))
# -> 1431 lines = self._plot(ax, data.index, data.values, style=style, **kwds)
#    1432 # set date formatter, locators and rescale limits
#    1433 format_dateaxis(ax, ax.freq, data.index)
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1555, in AreaPlot._plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1553 if column_num == 0:
#    1554     cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1555 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
#    1557 # need to remove label, because subplots uses mpl legend as it is
#    1558 line_kwds = kwds.copy()
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1466, in LinePlot._get_stacked_values(cls, ax, stacking_id, values, label)
#    1463 elif (values <= 0).all():
#    1464     return ax._stacker_neg_prior[stacking_id] + values
# -> 1466 raise ValueError(
#    1467     "When stacked is True, each column must be either "
#    1468     "all positive or all negative. "
#    1469     f"Column '{label}' contains both positive and negative values"
#    1470 )
#
# ValueError: When stacked is True, each column must be either all positive or all negative. Column 'Failure' contains both positive and negative values

# %%
network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_core.py:1557, in PlotAccessor.area(self, x, y, **kwargs)
#    1486 def area(self, x=None, y=None, **kwargs) -> PlotAccessor:
#    1487     """
#    1488     Draw a stacked area plot.
#    1489
#    (...)
#    1555         >>> ax = df.plot.area(x='day')
#    1556     """
# -> 1557     return self(kind="area", x=x, y=y, **kwargs)
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_core.py:1000, in PlotAccessor.__call__(self, *args, **kwargs)
#     997             label_name = label_kw or data.columns
#     998             data.columns = label_name
# -> 1000 return plot_backend.plot(data, kind=kind, **kwargs)
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/__init__.py:71, in plot(data, kind, **kwargs)
#      69         kwargs["ax"] = getattr(ax, "left_ax", ax)
#      70 plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 71 plot_obj.generate()
#      72 plot_obj.draw()
#      73 return plot_obj.result
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:452, in MPLPlot.generate(self)
#     450 self._compute_plot_data()
#     451 self._setup_subplots()
# --> 452 self._make_plot()
#     453 self._add_table()
#     454 self._make_legend()
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1382, in LinePlot._make_plot(self)
#    1379 label = self._mark_right_label(label, index=i)
#    1380 kwds["label"] = label
# -> 1382 newlines = plotf(
#    1383     ax,
#    1384     x,
#    1385     y,
#    1386     style=style,
#    1387     column_num=i,
#    1388     stacking_id=stacking_id,
#    1389     is_errorbar=is_errorbar,
#    1390     **kwds,
#    1391 )
#    1392 self._append_legend_handles_labels(newlines[0], label)
#    1394 if self._is_ts_plot():
#    1395
#    1396     # reset of xlim should be used for ts data
#    1397     # TODO: GH28021, should find a way to change view limit on xaxis
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1431, in LinePlot._ts_plot(self, ax, x, data, style, **kwds)
#    1428     decorate_axes(ax.right_ax, freq, kwds)
#    1429 ax._plot_data.append((data, self._kind, kwds))
# -> 1431 lines = self._plot(ax, data.index, data.values, style=style, **kwds)
#    1432 # set date formatter, locators and rescale limits
#    1433 format_dateaxis(ax, ax.freq, data.index)
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1555, in AreaPlot._plot(cls, ax, x, y, style, column_num, stacking_id, is_errorbar, **kwds)
#    1553 if column_num == 0:
#    1554     cls._initialize_stacker(ax, stacking_id, len(y))
# -> 1555 y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
#    1557 # need to remove label, because subplots uses mpl legend as it is
#    1558 line_kwds = kwds.copy()
#
# File ~/Documents/anaconda3/lib/python3.10/site-packages/pandas/plotting/_matplotlib/core.py:1466, in LinePlot._get_stacked_values(cls, ax, stacking_id, values, label)
#    1463 elif (values <= 0).all():
#    1464     return ax._stacker_neg_prior[stacking_id] + values
# -> 1466 raise ValueError(
#    1467     "When stacked is True, each column must be either "
#    1468     "all positive or all negative. "
#    1469     f"Column '{label}' contains both positive and negative values"
#    1470 )
#
# ValueError: When stacked is True, each column must be either all positive or all negative. Column 'Failure' contains both positive and negative values

# %%
network.generators_t.p.head().div(1e3).plot.area(subplots=True, ylabel="GW")
# Out:
# array([<Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>,
#        <Axes: xlabel='snapshot', ylabel='GW'>], dtype=object)

# %%
network.generators_t.p.min()
# Out:
# Generator
# Fossils           0.000000e+00
# BioEnergies       0.000000e+00
# Hydroelectric     1.303190e+03
# Wind_on_shore     8.600000e+02
# Wind_off_shore    6.800000e+02
# Nuclear           0.000000e+00
# Solar             0.000000e+00
# Failure          -3.637979e-12
# Curtailment       1.000000e+04
# dtype: float64

# %%
network.generators_t.p.idxmin()
# Out:
# Generator
# Fossils          1900-01-01 00:00:00
# BioEnergies      1900-01-01 00:00:00
# Hydroelectric    1900-06-03 12:00:00
# Wind_on_shore    1900-09-02 00:00:00
# Wind_off_shore   1900-09-01 21:00:00
# Nuclear          1900-01-01 00:00:00
# Solar            1900-01-01 00:00:00
# Failure          1900-01-01 00:00:00
# Curtailment      1900-01-01 00:00:00
# dtype: datetime64[ns]

# %%
network.generators_t.p['Failure'].head(30)
# Out:
# snapshot
# 1900-01-01 00:00:00   -3.637979e-12
# 1900-01-01 01:00:00   -3.637979e-12
# 1900-01-01 02:00:00   -3.637979e-12
# 1900-01-01 03:00:00   -3.637979e-12
# 1900-01-01 04:00:00   -3.637979e-12
# 1900-01-01 05:00:00   -3.637979e-12
# 1900-01-01 06:00:00   -3.637979e-12
# 1900-01-01 07:00:00   -3.637979e-12
# 1900-01-01 08:00:00   -3.637979e-12
# 1900-01-01 09:00:00   -3.637979e-12
# 1900-01-01 10:00:00   -3.637979e-12
# 1900-01-01 11:00:00   -3.637979e-12
# 1900-01-01 12:00:00   -3.637979e-12
# 1900-01-01 13:00:00   -3.637979e-12
# 1900-01-01 14:00:00   -3.637979e-12
# 1900-01-01 15:00:00   -3.637979e-12
# 1900-01-01 16:00:00   -3.637979e-12
# 1900-01-01 17:00:00   -3.637979e-12
# 1900-01-01 18:00:00   -3.637979e-12
# 1900-01-01 19:00:00   -3.637979e-12
# 1900-01-01 20:00:00   -3.637979e-12
# 1900-01-01 21:00:00   -3.637979e-12
# 1900-01-01 22:00:00    0.000000e+00
# 1900-01-01 23:00:00    0.000000e+00
# 1900-01-02 00:00:00    0.000000e+00
# 1900-01-02 01:00:00    0.000000e+00
# 1900-01-02 02:00:00    0.000000e+00
# 1900-01-02 03:00:00    0.000000e+00
# 1900-01-02 04:00:00    0.000000e+00
# 1900-01-02 05:00:00    0.000000e+00
# Name: Failure, dtype: float64

# %%
# %load_ext autoreload
# %autoreload 2

import gurobipy
# %pip install pypsa[highs] "xarray>=2023.8.0" Cartopy highspy

from gurobipy import *

import pypsa
import pandas as pd
from dataclasses import dataclass

full_demand = pd.read_csv("./data/demand_2030_scandinavia.csv", sep=";", index_col=1, parse_dates=True).groupby(pd.Grouper(key="climatic_year"))
full_wind_on_shore = pd.read_csv("./data/capa_factor_2030_scandinavia_onshore.csv", index_col=1, parse_dates=True, sep=";").groupby(pd.Grouper(key="climatic_year"))
full_solar = pd.read_csv("./data/capa_factor_2030_scandinavia_solar.csv", index_col=1, parse_dates=True, sep=";").groupby(pd.Grouper(key="climatic_year"))
full_wind_off_shore = pd.read_csv("./data/capa_factor_2030_scandinavia_offshore.csv", index_col=1, parse_dates=True, sep=";").groupby(pd.Grouper(key="climatic_year"))




climatic_year = 2000
time_horizon_in_hours = 365 * 24

demand = full_demand.get_group(climatic_year)
solar = full_solar.get_group(climatic_year)
wind_on_shore = full_wind_on_shore.get_group(climatic_year)
wind_off_shore = full_wind_off_shore.get_group(climatic_year)

network = pypsa.Network(snapshots=demand.index[0:time_horizon_in_hours])

network.add("Bus", name="Scandinavia", x=15.255119, y=60.128161)
network.add("Bus", name="Curtailment", x=10, y=65)
network.add("Bus", name="Poland", x=21.0117800, y=52.2297700)
network.add("Bus", name="Germany", x=13.4105300, y=52.5243700)
network.add("Bus", name="Benelux", x=4.3487800, y=50.8504500)
network.add("Bus", name="France", x=2.3488000, y=48.8534100)
network.add("Bus", name="Iberian", x=-3.7025600, y=40.4165000)

@dataclass
class Carriers:
    Battery = 0
    Biomass = 230
    Coal = 760
    Gas = 370
    Oil = 406
    Hydrogen = 490
    Hydro = 24
    Nuclear = 12
    Pumped = 0
    Reservoir = 0
    Solar = 45
    Wind = 11

for name, co2_emission in Carriers().__dict__.items():
    network.add("Carrier", name=name, co2_emissions=co2_emission)

#???
coal_marginal_costs = 160
gas_marginal_costs = 120
oil_marginal_costs = 100
nuclear_marginal_costs = 10
hydro_marginal_costs = 5
wind_marginal_costs = 5
solar_marginal_costs = 5
biomass_marginal_costs = 5


reservoir_max_hours = 365*24
pumped_max_hours = 100
battery_max_hours = 200
H2_max_hours = 300



#coal_marginal_costs = 128 / 7 / 0.37 
#gas_marginal_costs = 2.65 * 26.4 * 0.75 / 14.9 / 0.5
#oil_marginal_costs = 73 * 0.119 / 12.5 / 0.40

generators = [
    #{"name": "Coal", "carrier": "Coal", "p_nom": 2112, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": coal_marginal_costs, "efficiency": 0.37, "committable": True, "min_up_time": 1, "min_down_time": 1},
    #{"name": "Gas", "carrier": "Gas", "p_nom": 2640, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": gas_marginal_costs, "efficiency": 0.5,
    # "committable": True, "min_up_time": 1, "min_down_time": 1},
    #{"name": "Oil", "carrier": "Oil", "p_nom": 0, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": oil_marginal_costs, "efficiency": 0.4,
    # "committable": True, "min_up_time": 1, "min_down_time": 1},
    {"name": "Fossils", "carrier": "Fossils", "p_nom": 5000, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": gas_marginal_costs, "efficiency": 0.4,
     "committable": True, "min_up_time": 1, "min_down_time": 1},
    {"name": "BioEnergies", "carrier": "BioEnergies", "p_nom":11000, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": biomass_marginal_costs, "efficiency": 0.5, 
     "committable": True, "min_up_time": 1, "min_down_time": 1},
    {"name": "Hydroelectric", "carrier":"Hydro", "p_nom": 57000, "p_min_pu": 0, "p_max_pu": 1, "marginal_cost": hydro_marginal_costs, "efficiency": 1, "committable": True,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Wind_on_shore", "carrier": "Wind_on_shore", "p_nom": 43000, "p_min_pu":wind_on_shore.value, "p_max_pu": wind_on_shore.value, "marginal_cost": wind_marginal_costs, "efficiency":1, "committable": False,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Wind_off_shore", "carrier": "Wind_off_shore", "p_nom": 17000, "p_min_pu":wind_off_shore.value, "p_max_pu": wind_off_shore.value, "marginal_cost": wind_marginal_costs, "efficiency":1, "committable": False,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Nuclear", "carrier": "Nuclear", "p_nom": 11000, "p_min_pu":0, "p_max_pu": 1, "marginal_cost": nuclear_marginal_costs, "efficiency":1, "committable": True,
     "min_up_time": 24, "min_down_time": 24},
    {"name": "Solar", "carrier": "Solar", "p_nom": 19000, "p_min_pu":solar.value, "p_max_pu": solar.value, "marginal_cost": solar_marginal_costs, "efficiency":1, "committable": False,
     "min_up_time": 1, "min_down_time": 1},
    {"name": "Failure", "carrier": "Failure", "p_nom": 100000, "p_min_pu":0, "p_max_pu": 1, "marginal_cost": 100000, "efficiency":1, "committable": True,
     "min_up_time": 1, "min_down_time": 1},
    #{"name": "Curtailment", "carrier": "Curtailment", "p_nom": 100000, "p_min_pu":1, "p_max_pu": 1, "marginal_cost": 0, "efficiency":1, "committable": True,
     #"min_up_time": 1, "min_down_time": 1},
]

fictive_generator = [
    {"name": "Curtailment", "carrier": "Curtailment", "p_nom": 100000, "p_min_pu":0, "p_max_pu": 1, "marginal_cost": 0.0001, "efficiency":1, "committable": True,
     "min_up_time": 1, "min_down_time": 1}
]


storage_units = [
        {"name": "Reservoir", "carrier": "Reservoir", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": reservoir_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" : 100, "p_nom_charge" : 100},
        {"name": "Pumped", "carrier": "Pumped", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": pumped_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" : 100, "p_nom_charge" : 100},
        {"name": "Battery", "carrier": "Battery", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": battery_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" : 100, "p_nom_charge" : 100},
        {"name": "H2", "carrier": "H2", "p_nom": 100000, "p_min_pu": 0, "p_max_pu": 1, "max_hours": H2_max_hours, "efficiency": 1, "cyclic_state_of_charge": True, "p_nom_discharge" :100, "p_nom_charge" : 100},
]





for generator in generators:
    network.add("Generator", bus="Scandinavia", **generator,)
    
for generator in fictive_generator:
    network.add("Generator", bus="Curtailment", **generator,)
#for storage in storage_units:
#    network.add("Store", bus="Scandinavia", **storage,)

#'carrier', "AC" ?? 

loads = [
    {"name": "Scandinavia-load", "bus": "Scandinavia", "carrier": "AC","p_set": demand[0:time_horizon_in_hours]["value"].values*1},
    {"name": "Curtailment-load", "bus": "Curtailment", "carrier": "AC","p_set": 10000},
]   

for load in loads:
    network.add("Load", **load)

links_list = [
    {"name" : "Link_SCA_Curtailment", "bus0" : "Scandinavia", "bus1" : "Curtailment", "p_nom" : 700000, "efficiency" : 0.95},
    {"name" : "Link_SCA_Germany", "bus0":"Scandinavia", "bus1":"Germany", "p_nom":7415, "efficiency":0.95},
    {"name" : "Link_SCA_Poland", "bus0":"Scandinavia", "bus1":"Poland", "p_nom":600, "efficiency":0.95},
    {"name" : "Link_SCA_Benelux", "bus0":"Scandinavia", "bus1":"Benelux", "p_nom":1400, "efficiency":0.95},
    {"name" : "Link_Benelux_SCA", "bus0":"Benelux", "bus1":"Scandinavia", "p_nom":1400, "efficiency":0.95},
    {"name" : "Link_Poland_SCA", "bus0":"Poland", "bus1":"Scandinavia", "p_nom":0, "efficiency":0.95},
    {"name" : "Link_Germany_SCA", "bus0":"Germany", "bus1":"Scandinavia", "p_nom":2000, "efficiency":0.95},
    {"name" : "Link_France_Germany", "bus0":"France", "bus1":"Germany", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_France", "bus0":"Germany", "bus1":"France", "p_nom":3300, "efficiency":0.95},
    {"name" : "Link_Germany_Poland", "bus0":"Germany", "bus1":"Poland", "p_nom":3400, "efficiency":0.95},
    {"name" : "Link_Poland_Germany", "bus0":"Poland", "bus1":"Germany", "p_nom":3400, "efficiency":0.95},
    {"name" : "Link_Germany_Benelux", "bus0":"Germany", "bus1":"Benelux", "p_nom":9300, "efficiency":0.95},
    {"name" : "Link_Benelux_Germany", "bus0":"Benelux", "bus1":"Germany", "p_nom":9300, "efficiency":0.95},
    {"name" : "Link_Benelux_France", "bus0":"Benelux", "bus1":"France", "p_nom":4680, "efficiency":0.95},
    {"name" : "Link_France_Benelux", "bus0":"France", "bus1":"Benelux", "p_nom":4680, "efficiency":0.95},
    {"name" : "Link_France_Iberian", "bus0":"France", "bus1":"Iberian", "p_nom":5000, "efficiency":0.95},
    {"name" : "Link_Iberian_France", "bus0":"Iberian", "bus1":"France", "p_nom":5000, "efficiency":0.95},
]

for links in links_list:
    network.add("Link", **links,)

#network.add("Link",
#            "Link_SCA_Curtailment",  # Unique identifier for the link
#            bus0="Scandinavia",    # Name of the first country/bus
##            bus1="Curtailment",    # Name of the second country/bus
 #           p_nom=700000,           # Transmission capacity in MW (adjust as needed)
 #           efficiency=0.95,      # Transmission efficiency (adjust as needed)
 #          )

network

network.plot(
    title="European Electricity Network",
    color_geomap=True,
    jitter=0.3,
)

result = network.optimize(solver_name="gurobi")
print(result)   

network.generators.p_nom_opt.div(1e3).plot.bar(ylabel="GW", figsize=(8, 3))

network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=False, ylabel="GW")

network.generators_t.p.resample('D').mean().div(1e3).plot.area(subplots=True, ylabel="GW")

network.generators_t.p.head().div(1e3).plot.area(subplots=True, ylabel="GW")

network.generators_t.p.min()

network.generators_t.p.idxmin()

network.generators_t.p['Failure'].head(30)
